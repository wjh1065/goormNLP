# %% [markdown]
# # 과제 2. 나만의 데이터 셋 만들기
# 기계 학습 분야에서 중요한 것 중 하나가 학습에 사용할 자료를 수집하고 관리하는 것입니다.
# 예를 들어 주어진 문장이 부정인지 긍정인지 판별하는 모델을 학습 시키기 위해서는 긍정 부정이 라벨링된 문장 자료가 필요합니다.
#
# 문장 | 긍부정
# -------|--------
# 진짜 좋은 영화. 가히 올해의 영화라고 불릴만하다. | 긍정
# 이런 영화에 100억원 이상 때려 넣은 감독은 충무로에서 쫓겨나야한다. | 부정
#
# 그러나 우리가 이러한 자료를 직접 수집 및 라벨링하기는 쉽지 않다.
#
# 한편, 내부 연구나 교육적 목적으로 이미 가공된 인터넷의 글들을 수집하는 것은 공정이용으로 저작권법에 어긋나지 않습니다.
# 따라서 네이버 영화 리뷰를 크롤링하여 나만의 긍부정 문장 데이터 셋을 만들어 봅시다.

# %% [markdown]
# ## 2-1. 네이버 영화 리뷰 크롤링 (40점)
# 현재 상영 중인 영화에 대한 영화 한 줄 평은 다음 링크에서 확인 가능합니다.
#
# [https://movie.naver.com/movie/point/af/list.naver?&page=1](https://movie.naver.com/movie/point/af/list.naver?&page=1)
#
# 네이버 영화 한줄평의 주소는 다음과 같이 `<페이지 숫자>`에 해당되는 숫자를 넣으면 해당 페이지를 불러오는 것이 가능합니다.
#
# https://movie.naver.com/movie/point/af/list.naver?&page= `<페이지 숫자>`
#
# 이러한 접근을 통해 영화 한 줄 평을 끍어모아 다음과 같은 형태의 `CSV` 파일로 저장하는 코드를 만들어 봅시다.
#
# movie | sentence | score
# ------|------|------
# 모가디슈 | 재미잇게 잘봤습니다. 배우들 연기에 더몰입감있게 봤습니다. | 10
# 낙원의 밤 | 차승원의 유머만 남은 흉내 낸 누아르, 결말조차 완벽하게 폭망 | 2
# 국화꽃 향기 | 뭔가 와닿지 않는 감동 그리고 스토리. 아쉽지만 여운이 남지 않는다 | 4
# 미쓰 홍당무 | 서우가 아주 매력적으로 나오는 영화 | 8
# 더 수어사이드 스쿼드 | 후련하게 봤어요 재밌네요ㅋㅋㅋ잔인하고 징그러운거 좋아하시는 분들께 추천 | 9
#
# ### 크롤러를 만들때 다음과 같은 사항을 준수해야 합니다.
# 1. 실제 학습을 진행할 것은 아니기 때문에 문장은 1000개 정도만 가져오면 충분합니다.
# 2. 각 페이지를 조회하실때 시간차가 없다면 DDOS 공격으로 분류되어 페이지 접속이 막힐 수가 있습니다. 페이지 조회시 최소 0.5초의 시간 차를 둡시다.
# 3. 신고되어 삭제된 한줄평은 데이터에 들어가면 안됩니다. 또한 한줄평이 아예 없는 경우도 제외하셔야 합니다.
# 4. 사용 가능한 라이브러리는 다음과 같습니다.
#     * 파이썬 표준 라이브러리
#     * Request
#     * Beutiful Soup
#     * (For colab user) Colab
#     * (Optional) Scrapy
# 5. `CSV` 파일로 저장하실때 Unicode로 저장하셔야 하며, Excel에서 문제 없이 열 수 있어야 합니다.
# 6. `CSV` 파일은 쉼표로 구분되어야 합니다.
# 7. `CSV` 파일의 레코드 형식은 다음과 같습니다.
#   * movie - 영화 이름이 들어갑니다. 문자열입니다.
#   * sentence - 한줄평이 들어갑니다. 문자열입니다.
#   * score - 별점이 들어갑니다. 숫자입니다.
# 8. 크롤링 코드를 실행하여 크롤링을 한 번에 완료해야 합니다.
# 9. 그외 상세한 구현 방법은 자율입니다.
#
# ### 과제를 제출하실때 다음을 제출해야합니다.
# 1. 크롤링된 데이터를 저장한 `samples.csv`
# 2. 크롤링 코드

# %% [markdown]
# ---
#
# # 네이버 영화 리뷰 크롤링 (이창석)
#
# ---

# %% [markdown]
# ### Step 1. 네이버 영화 리뷰 데이터 크롤링.

# %%
import time, random
from tqdm import tqdm

import requests
from urllib import parse
from bs4 import BeautifulSoup

base_url = 'https://movie.naver.com/movie/point/af/list.naver?&page={}'

data_list = []
for page in tqdm(range(1,111)):
    url = base_url.format(page)
    res = requests.get(url)
    soup = BeautifulSoup(res.text)
    titles = soup.select('tr > td.title')
    for title in titles:
        movie = title.select_one('a.movie').text.strip()
        sentence = title.select_one('br').next_sibling.strip()
        if not sentence:
            continue
        score = title.select_one('div.list_netizen_score > em').text.strip()
        data_list.append((str(movie),str(sentence),int(score)))
    interval = round(random.uniform(0.2,1.2),2)
    time.sleep(interval)
# Out:
# 100%|█████████████████████████████████████████| 110/110 [01:39<00:00,  1.10it/s]

# %% [markdown]
# ### Step 2. 크롤링 된 데이터 확인.

# %%
import csv

fields = ['movie', 'sentence', 'score']

with open('samples.csv', 'w',encoding = 'utf-8-sig') as f:
    write = csv.writer(f, delimiter=',',
                      quotechar='"',
                      quoting = csv.QUOTE_MINIMAL)
    write.writerow(fields)
    write.writerows(data_list)


with open('samples.csv', 'r',encoding = 'utf-8-sig') as f:
    reader = csv.reader(f, delimiter=',',
                      quotechar='"',
                      quoting = csv.QUOTE_MINIMAL)
    
    for row in reader:
        print(row)
# Out:
# ['movie', 'sentence', 'score']
# ['스파이더맨: 노 웨이 홈', '시리즈가 주는 감동이 어마어마하다ㅠ', '10']
# ['미스 슬로운', '신념 있는 로비스트는 자신의 승리만을 믿지 않는다.', '7']
# ['퍼스트 카우', '마지막 급박한 순간조차도 비로소 둘이 함께 일 때 가장 편안하고 안락함을 느꼈던 두 사람의 우정.', '8']
# ['공작조: 현애지상', '암살을 눈탱이질한 후에 영감을 받았다며 일을 벌인 장이모우의 최후...태극기 휘날리며 눈탱이질한 집결호 만큼이나 뜬금없다...', '6']
# ['용쟁호투', '이소룡 몸과 표정을 보고 있으면 시간이 후딱 지나감.', '9']
# ['크리스마스로 불리는 소년', '쥐가 캐리한 영화 ㅋㅋㅋㅋ', '10']
# ['우아한 거짓말', '원작도 재밌게 읽었는데 원작만큼 재밌었어요', '10']
# ['스플릿', '두꺼비는 내 인생 최고의 악역이다ㅋ아직도 줘패주고싶네 두꺼비새끼 (칭찬임)', '10']
# ['씽2게더', '마지막 장면 30분은 그냥 최고... 꼭 영화관에서 보세요', '8']
# ['안시성', '병두야 연기 때려치자 그냥', '1']
# ['경관의 피', '보면서 물음표가 많이 나오는 영화였어요 뭔가 말하고 싶은것은 많는데 제대로된 메시지는 없는 난잡한 스토리였어요', '6']
# ['제인 에어', '마음이 간드러지는 영화', '8']
# ['소녀의 세계', '영상미가 너무좋네요 뿜뿜', '10']
# ['낙원의 밤', '잠깐 나온 이문식 연기력만 10점 준다 ㅋㅋㅋㅋ진짜 남는거 아무것도 없이 기분만 더러운 영화', '1']
# ['자산어보', '왜 인간은 인간이 갈길을 모르는걸까', '6']
# ['경관의 피', '쓸대없이 여배우 안쓰고 간만에 재밌게본 한국영화', '8']
# ['스파이더맨: 노 웨이 홈', '코로나 장기화로 지친 시기에 만나는 역대급 블록버스터', '10']
# ['경관의 피', '재밋어요 지루하지않아요!!!', '10']
# ['씽2게더', '최고~개인적으로 1편보다 좋았음', '10']
# ['둠스데이 - 지구 최후의 날', '이게 바로 진짜 헐리우드 B+급이지 ㅋㅋㅋㅋ', '2']
# ['고스트버스터즈 라이즈', '아 그때 그 추억. 짜릿한 등장.', '9']
# ['오아시스', '소름이돋는 연기… 지금의 저 배우들을 보면 정말저 시대와 같은 분들이었을까라는의심에 더 소름이 돋는다…배우는배우다!!!', '10']
# ['스파이더맨: 노 웨이 홈', '액션도 스토리도 지금까지 시리즈 중 최고였어요 ㅠㅠ 꼭보세여', '9']
# ['스파이더맨: 노 웨이 홈', '옛 스파이더 주인공들과 현 스파이더맨 한 화면에 나올줄이야.. 정말 상상도 못했습니다. 어린시절 추억들과 지금의 감성까지 모두 다 잡은 최고의 영화!', '10']
# ['사랑의 블랙홀', '사랑스러운 영화 ^^ 벌써 30년이나 되었네요', '10']
# ['스파이더맨: 노 웨이 홈', '2021 최고의 영화', '10']
# ['킹스맨: 퍼스트 에이전트', '너무재미있었습니다 진짜 최근본 영화중 원탑', '10']
# ['아이스 데몬', '썰렁한 괴담', '4']
# ['2012', '옛날에 참 재밌게 봤던 기억이 있어서 오랜만에 다시 봤는데…무려 13년 전 영화. 어릴때 봤던거라 그냥 아무것도 모르고 재미있었던거였음. 지금 보니 억지스러운게 한 두가지가 아님. 그냥 다 쓰러지고 터지고 하니까 재밌었던거지 ㅋㅋ 그래도 재난영화는 좋아하는 편이라 무난하게 봄', '6']
# ['그녀에게', '사랑 그 이전의 결핍에 대하여', '10']
# ['프렌치 디스패치', '영상미는 완벽 ..대사가 많아 조금 힘들었음', '8']
# ['아수라', '영화가 정신사납기만하네초반에 뜬금없이 맥주병으로왜때리는거요', '1']
# ['오늘부터 히어로', 'good for 10 years old child', '10']
# ['타짜', '명작은 다시봐도 명작 ...', '10']
# ['싱크홀', '와 감상포인트 뭘 눌러야할지 모르겠네다섯개 다 해당 안하는데??? 이렇게 애매한 영화는 처음임그나마 연출? CG는 진짜 별론데마지막에 물탱크 등장하는거에서 어이없게 웃어서 그거 하나때문에 별 4점이라도 줌.개인적으로 배우진들 진짜.. 다 좋아하는데 이 배우들 갖다놓고 이렇게 찍었다는게…', '4']
# ['스파이더맨: 노 웨이 홈', '먼저 본 사람들이 눈물이 날거야라고 해서.. 무슨 신파길래 눈물 타령인가.. 난 관심없다 했는데.. 왜 눈물이 날거라고 얘기했는지 알겠음.파커 파커 파커', '10']
# ['스파이더맨: 노 웨이 홈', '썸남이랑 보러 갔었는데 영화가 너무 엄청나서 아무 일도 일어나지 않았습니다.', '10']
# ['컨테이젼', '영화가 아니라 다큐보는 기분..', '8']
# ['신의 손', '소년의 성장을 담은 영화', '7']
# ['드라이브 마이 카', '오랜만에 느껴보는 호흡 ㅜ 너무 잘봤습니다', '10']
# ['유 콜 잇 러브', '좋아하는 노래 ^^너무 예쁜 소피마르소^^', '8']
# ['매드맥스: 분노의 도로', '이거만큼 쾌감쩌는영화 본적없음', '10']
# ['언포기버블', '산드라블록의 연기가 최고..', '8']
# ['킹스맨: 퍼스트 에이전트', '서양 세계사를 아는 사람은 더 재밌게 볼 수 있어요.', '7']
# ['극적인 하룻밤', '개 노 잼 & 개 연 성 없 음그냥 윤계상 한예리가 귀여움', '1']
# ['틱, 틱... 붐!', '앤드류의 연기가좋고 넘버들도 완벽', '9']
# ['비스티 보이즈', '뭔 스토리도 없고 그냥 호빠들 자잘한 거짓말과 사기만 치는 얘기말고 암것도 없고 내용자체도 더러움', '4']
# ['돈 룩 업', '현실반영이 잘된 영화지만 나에겐 웃기지는 않은 ..', '5']
# ['유체이탈자', '거울을 이용한 연출이 좋았던 영화', '7']
# ['스파이더맨: 노 웨이 홈', '다시 마블을 찾아보기 시작했다', '10']
# ['익스트랙션', '6점도 높은거… 크리스 헴스워스 연기때문에 다 봤음. 스토리가 엔간치 해야지 뻔하디 뻔한 스토리에… 애 하나 구하겠다고 손해를 얼마나 본거냐. 돈도 못 얻고 팀원도 잃고~ 그래도 액션씬 하나는 볼만했음. 연출은 우리나라식 B급 갬성을 보는 것 같아 영 별론데 액션씬 + 연기력 하나 때문에 6점 줌.', '6']
# ['라스트 모히칸', '정말 재밌고 감동적으로 본 영화임.예전 영화관에서 봤는데 오늘 TV에서 다시 보니추억의 명화를 다시 접해서 행복하네요.', '10']
# ['넬리', '보는 중에는 되게 자기 파괴적이라고 생각했으나 그녀에게서 나를 보았다. 스스로에겐 확신이 없고 외로운, 순간순간 아끼는 사람들에게 온전히 마음 내어주고 휩쓸리는 그녀란...', '10']
# ['킹스맨: 퍼스트 에이전트', '예전시리즈와는 다른 재미!', '8']
# ['늑대아이', '너무…아무생각없이 봤다가 질질짰어요ㅠㅠㅠ 아진짜ㅠ', '10']
# ['경관의 피', '중반까지는 좋았으나 결말에 이를수록 오히려 긴장감이 풀어지며 이야기가 흐지부지 되는 느낌. 그리고 대사 전달력이 별로 안 좋다.', '7']
# ['공수도', '보는내내 재밌어요. 추천', '10']
# ['고스트버스터즈 라이즈', '개인적으로 성공적인 리부트라 생각합니다.재밌게 봤어요...마지막에 이곤이 나왔을 땐...감동적이었습니다.', '10']
# ['스파이더맨: 노 웨이 홈', '맘껏 기대해도 좋은 스파이더맨 최고영화!', '10']
# ['스파이더맨: 노 웨이 홈', '제 인생을 되돌아보게된 영화 선물 감사합니다.', '10']
# ['스파이더맨: 노 웨이 홈', '이 영화가 천만을 못 찍으면 충격일듯. 코로나 시국 속 최고의 히어로 무비', '10']
# ['스파이더맨: 노 웨이 홈', '진짜 감동적이다 3스파', '8']
# ['매트릭스: 리저렉션', '전 재밌게 봤습니다. 1,2,3편을 보지 않았던 터라 매트릭스 세계관을 수박 겉핥기식으로 알고 있었는데요. 덕분에 내용에 혼돈이 쎄게 와서 나무위키를 참고하며 보았습니다. 스토리를 알고나니 무척이나 재밌더라구요. 그리고 매트릭스 1,2,3편이 보고 싶어지더군요. 다만 네오와 트리니티의 초인적인 능력은 마블 슈퍼 히어로급이던데요. 액션신은 볼만했습니다.근데 여기도 PC가 묻었는지, 조금 그런 배역들이 보이더라구요. 매트릭스 포에버. 다음 작품도 기대하겠습니다! 역시 명불허전이네요~', '8']
# ['씽2게더', '1편보다 커진 스케일과 화려한 영상, 그리고 흥겨운 음악들이 즐거움을 선사한다. 다만 스토리는 여전히 아쉽다.', '7']
# ['그린 마일', '명작이다 이 감정을 말로 표현 못하겠다 ,추천합니다', '10']
# ['스파이더맨: 노 웨이 홈', '히어로영화 잘 안 보는데도 재밌게봤음', '10']
# ['돈 룩 업', '재미있었나요? 야금야금 환경오염으로 종말을 맞이중이지만 아무도 플리스틱과 비닐,기름의 사용을 멈추지 않는 우리의 진짜 현실을 풍자한겁니다.', '10']
# ['방법: 재차의', '중반 이후부터는 그냥 삼류 판타지 영화.', '5']
# ['돈 룩 업', '혜성대신 백신을 대입하면 딱 맞네요', '10']
# ['스파이더맨: 노 웨이 홈', 'ㄹㅇ 코시국만 아니었으면 1000만 영화임 ㅇㅈ', '10']
# ['유체이탈자', '한국에서 이런 수작이 나오다니sf 특성상 약간의 오류들이 아쉬웠고액션이 좋기도하면서도 아쉬웠다', '10']
# ['킹스맨: 퍼스트 에이전트', '이전보다 절제된 영상미, 시리즈물로 거듭나기 위한 밑거름이 되는 작품', '9']
# ['씽2게더', '문재앙 ~.~ ~.~ ~.~', '10']
# ['경관의 피', '진짜 악역은 누구일까....', '10']
# ['경관의 피', '대존잼입니다. 진짜 눈물질질짜는 신파포인트없고 깔끔하고 좋았습니다.조진웅이 조진웅했다. 최우식이 최우식했다. 기생충지하방아저씨도 한몫했다!', '10']
# ['엔칸토: 마법의 세계', '예고편에서 기대했던 것 보다 뭔가 아쉬운 느낌.', '8']
# ['싸나희 순정', '치유를 위한 억지설정들', '4']
# ['캐빈 인 더 우즈', '야 이거 뭐냨ㅋ크케켁 시간 순삭', '10']
# ['스파이더맨: 노 웨이 홈', '올해 최고의 영화', '10']
# ['아저씨', '최고중에 최고지  역대급임', '10']
# ['프로메테우스', '아니 이 명작이 왜 평점이 이따위냐?이건 그야말로 작품이다', '10']
# ['뮬란', '만화 뮬란이 워낙 인상이 깊다보니 꼭 보고 싶어서 망작이라는 이야기를 들었지만 봤습니다. 하.. 남의 말은 주의깊게 들어야 하는건데 ... 아니 그 명작을 어떻게 이렇게까지 할 수가 있지. 뮤지컬은 어디로 사라지고 설정은 개판에 감동도 없고 진짜 미쳤나 정신이 나갔나 하 개열받네 내 감동 돌려내라. 그래도 배우 캐스팅을 좀 해서 연기는 그럭저럭? 그런 개떡같은 설정에도 괜찮더군요. 생각없이 보면 볼면할지도 모르겠네요.', '1']
# ['전장의 피아니스트', '잠시나마 그들의 고통에 공감할 수 있었다. 마냥 재밌게 볼 수 있는 영화는 아닌듯.', '7']
# ['경관의 피', '진짜 저만 재미없게봤나. 평점들이 좋네요. 명품배우들 모시고 .. 기대가 컸나. . 최근본 영화 강릉 영화보다 한수위네요. ㅜ', '1']
# ['담보', '너무 감동 ㅜㅜ 엄청 울었네 ㅜㅜ', '10']
# ['파이란', '안타깝고 마음찡하네요 오래도록 제맘속에 남을거에요 세번째 봅니다', '10']
# ['매트릭스: 리저렉션', '부활하지 말았어야할 영화', '4']
# ['경관의 피', '좋은영화입니다 꼭 보세요 짱 입니다', '10']
# ['경관의 피', '한 4점쯤 주고 싶은데 10점 주는 알바들 때매 1점 줌. 지루하고 폼잡는 90년대 한국영화 본 느낌… 보다가 마스크까지 끼고 내가 뭘보고 있나 싶었음', '1']
# ['반도', '영화시작 10분도 안돼서 신파 깔기 시작. 그래 신파 좋다 이거야. 근데 브금은 무슨 영화 끝나는 수준으로 웅장함 ㅋㅋㅋ', '2']
# ['씽2게더', '다른말 필요없음,,진짜 최고였어요!!!', '10']
# ['건달티처', '유튜브로 하이라이트만 보는데도 오글거려서 스킵하면서 봤네요', '1']
# ['돈 룩 업', '간만에 본 재미 있는 영화~', '10']
# ['킹스맨: 퍼스트 에이전트', '재밌게 봤어요!! 개인적으로는 스파이더맨보다 재밌게봄..', '9']
# ['연애 빠진 로맨스', '중반 9점 후반 5점 전종서10점', '7']
# ['드라이브 마이 카', '이 영화를 보고 확신이 생겼다. 일본은 정신분열 상태에 빠져있다.', '4']
# ['스파이더맨: 노 웨이 홈', '연기를 다들 잘하셔요~', '10']
# ['덩케르크', '2차 대전 다큐 보고 봤더니 더 감동이다.', '10']
# ['우주 전쟁', '애ㅅㄲ들은 뒤ㅈ는게 맞다', '8']
# ['스파이더맨: 노 웨이 홈', '감사합니다', '10']
# ['위시 드래곤', '재미는 있으나, 구성은 알라딘', '6']
# ['스파이더맨: 노 웨이 홈', "'로건'과 더불어 진정한 팬서비스가 뭔지 제대로 보여주는 슈퍼히어로 영화", '7']
# ['스파이더맨: 노 웨이 홈', "'로건'과 더불어 진정한 팬서비스가 뭔지 제대로 보여주는 슈퍼히어로 영화", '7']
# ['경관의 피', '이게 평점이 왜 낮지???? 진짜 간만에 재밌게 본 한국영화!!!! 백신패스관에서 꿀잼이었음!!!', '10']
# ['씽2게더', '콘서트 다녀온거 같다조니 넘 잘해~', '10']
# ['언포기버블', '그녀가 울먹일 때 같이 울었고 그녀가 안길 때 같이 울었다. 평론가 분리수거바랍니다', '10']
# ['램', '스웨덴의 자연풍광과 목가적 분위기는 좋았지만  스토리는 진짜 별로', '6']
# ['불한당: 나쁜 놈들의 세상', '말이안되는 스토리.. 임시완 배역 자체가 말이안됨', '2']
# ['씽2게더', '새해에 어울리는 화려한 뮤지컬!유명한 팝송이 많이 나와서 반갑다', '7']
# ['돈 룩 업', '인류종말 버라이어티쇼', '10']
# ['경관의 피', '사운드 별로라하는데 잘들리고 재밋엇름', '10']
# ['타이거마스크', '재미없음유치함 내용없음 킬링타임용도 아닌 시간 낭비', '1']
# ['씽2게더', '이건 진짜 최고네요! 전율입니다!', '10']
# ['해피 뉴 이어', '가볍게 보기 좋네요.', '7']
# ['경관의 피', '최우식이 귀여워서 몰입 안됨', '10']
# ['아야와 마녀', '저기 저는 개인적으로 별로예요 잠이 왔어요....지루', '2']
# ['화이트: 저주의 멜로디', '어렸을 때 봤던 공포영화 중에 제일 무섭게 봤음! 특히 후반부 장면은 아직도 기억에 남음', '10']
# ['엘도라도', '어릴때 영화 갑자기 생각나서 들어와봤음 진짜 재밌었는데', '10']
# ['씽2게더', '뮤지컬 영화 좋아하면 강력추천!!!', '10']
# ['유열의 음악앨범', '그시절 그리움이 밀려오는 스토리', '10']
# ['스파이더맨: 노 웨이 홈', '다른건 몰라도 이건 꼭 보세요', '10']
# ['허드 앤 씬', '뭐 이정도면 생각보다 재밌는데?', '10']
# ['모글리: 정글의 전설', '동물들 생김새도 그렇고 전개도 좀 이상하고 현실성도 너무 떨어지네여', '2']
# ['인크레더블 헐크', '헐크같은 남친있으면 든든하겠당 ㅋㅋㅋ 강아지 넘 불땅... ㅜ 마지막 장면에서 소름돋음 이렇게 연결되는거구나 ㅋㅋ', '9']
# ['람보 : 라스트 워', '마귀들 심판하는 람보 최고!', '10']
# ['경관의 피', '사운드 안좋다는 이야기가 나오면 어케!', '6']
# ['고스트버스터즈 라이즈', '새로운 고스트버스트의 시작을 기대합니다.', '10']
# ['드라이브 마이 카', '한장면 한장면 소중히 아름답게 기억하고싶은 영화', '10']
# ['해피 뉴 이어', '따뜻한  결말이   있는  스토리라서  넘  좋았어요.해마다 12월 이 되면  꼭  보고싶을  영화', '10']
# ['그것만이 내 세상', '완전 감동였어요 긴 여운이 남는구성 잘 된 영화이네요', '10']
# ['스파이더맨: 노 웨이 홈', '스파이더맨과 관련한 모든 추억의 총집합', '10']
# ['경관의 피', '좋아하는배우들의 연기와 반전있는 시원한 스토리 재밌게봤습니다 :)', '10']
# ['스파이더맨: 노 웨이 홈', '역시 마블 넘 재밌었습니다', '10']
# ['파이란', '내 인생 최고의 영화..', '10']
# ['이터널스', '진짜 제일 재미없다개인적으로비추천합니다', '1']
# ['아멜리에', '20년이 지났는데도 여전히 좋은 영화는 흔치 않다', '10']
# ['언포기버블', '큰 대사없이도 감정이입이 되는 산드라블록의 연기에 눈시울이 붉어지네요 ... 절대 후회없는 영화입니다.', '10']
# ['경관의 피', '연기는 두말할것 없고! 선과 악이 구분되지 않아 그럴수도~라는 공감이 되는 스토리~ 스팩타클 하거나 반전이 있는 영화는 아니고~ 걍 재밌게 봤다~정도', '9']
# ['스파이더맨: 노 웨이 홈', '내용 액션을 떠나서 추억을 회상해서 좋았습니다.. 반가운 얼굴들..', '9']
# ['사랑을 놓치다', '22년에 이 영화를 보려니 힘드네요. 이별에 괴로운 남주는 공중전화를 부수고,다 마신 소주병을 깨고, 친구가 맡긴 개랑 신경전을 벌이다 폭력을 휘두르고(소리로만 나왔지만) 개가 쓰러지고 발발 떠는 모습이... 이 영화의 유머코드인가요...이때쯤 나온 한국영화 거의 다 봤고, 배우들이 꺼려져 뒤늦게 보는데 15년 전 영화라고 감안하고 보더라도다른 데서는 못 느낀 불쾌한 요소가 있네요.', '2']
# ['귀를 기울이면', '넷플에서 아무 생각 없이 틀고 보다가흠뻑 빠졌습니다2022년에 봐도 전혀 촌스럽지 않고너무 집중이 잘되네요혹시 차기작이나 다른 작품 있을까감독 검색 해봤는데 98년도에 돌아가셨네요..제 인생영화라고 마음속에 간직하고싶은 영화입니다', '10']
# ['스파이더맨: 노 웨이 홈', '사람은 신념을 남긴다. 라는 말이 인상깊게 와닿네요. 따뜻한 신념으로 세상을 따뜻하게 적시고 간 메이와 그를 따를 피터파커, 저도 함께 물들고 싶어요. 그 따뜻한 물결의 파동 아래.', '10']
# ['나는 조선사람입니다', '조선인이라고 하니까 북한 사람만 가리키는 줄 알았는데 아니였네요. 분단 되기전에 건너간 사람들한테는 북이나 남이나 조선반도가 너무나 소중한 고향이라는 걸 처음으로 알게 되었어요.', '10']
# ['스파이더맨: 노 웨이 홈', '코로나 터지고 봤던 영화 중에 돈이 안 아까웠음 더 내고 싶은 정도임', '10']
# ['씽2게더', '최고의 장점으로 단점을 가려버리는 멋진 쇼비지니스', '8']
# ['엔칸토: 마법의 세계', '의외로 재밌었어요!! 역시 디즈니 :)', '10']
# ['경관의 피', '장면이 너무 휙휙 바뀜..개연성이 별로..', '4']
# ['타짜', '다시봐도 재밌다!', '10']
# ['씽2게더', '유치하고 진부한 스토리지만 음악이 좋았어요', '6']
# ['미스터 보스', '최악 최악 최악 뭐지  최악 쓸ㄱ', '1']
# ['괴물', '어릴 때 봤던 괴물을 오랜만에 다시 봤다. 마치 요즘의 현실과 겹쳐 보여 더 특별하게 느껴진 영화. 별 것도 아닌 바이러스에 지나칠 정도로 통제하며 백신을 강요하는 정부가 영화 속 결국 형체도 없는 바이러스로 세계를 속이는 모습과 다를 게 없다. 그 상황 속에서 아무것도 모르고 도망치고 통제 받는 시민들. 그러나 결국 상황을 타개하고 일어나려 하는 것 또한 시민들. 10여년이 지났지만 영화 속 괴물은 현실에서 여전히 존재하네.', '10']
# ['돈 룩 업', '극사실주의 영화. 미디어와 정치 상황, 진실에 관심 없고 감각만 쫒는 세태를 너무 잘 담았다. 웃기면서 혐오스럽고 무서운 영화.', '10']
# ['고스트버스터즈 라이즈', '항상 어중간한 꼽사리로 명작 망치는 PC, 꼴페들 잘 보고 반성하길. 2016작품은 당연하고 개인적으로 매트릭스4도 이겼다고 본다.', '10']
# ['차일드 인 타임', '베네딕트 연기 진짜 미친듯..', '10']
# ['모가디슈', '억지신파 없음 액션 시원  깔끔한 연출 좋은연기안 볼 이유가 없음 .', '10']
# ['스파이더맨: 노 웨이 홈', '개노잼은 엠씨구리 아빠입니다', '2']
# ['경관의 피', '오늘 보고 왔는데 음향팀은 나가 죽으세요..', '4']
# ['고스트버스터즈 라이즈', '완전 초딩영화가 됬노.. 갈수록 망가지는 고스트버스터다..', '2']
# ['씽2게더', '노래도 좋고 뮤지컬 스케일도 엄청 커져서 보는 재미가 더 커졌음마지막엔 살짝 눈물도 났다 감동 ㅠㅠ', '9']
# ['새해전야', '여러분 진심으로 보지마세요 1540원 지불 한것도 아까워요 끝까지 못 본 영화는 클레멘타인 이후로 처음입니다', '1']
# ['경관의 피', '재밌게보고왔습니다~생각보다잼있어요기다이상~', '10']
# ['타워', '재미없음집중안됨ㅜㅜ', '2']
# ['스파이더맨: 노 웨이 홈', '진짜 삼스파 함께 싸우는 거 지리더라 삼스파 공통점도 많았고 이건 영화관에서 봐야한다', '10']
# ['돈 룩 업', '재난영화를 이렇게 풀어낼수있다는게 그저 놀랍다', '9']
# ['돈 룩 업', '평점이 생각보다 좋네요 저는 노잼이었어요...디카프리오 나와서 끝까지 봤네요', '4']
# ['경관의 피', '마지막이 뭔가 생략된 것 같은 느낌이라 좀 아쉽긴 했지만... 배우님들 연기력도 몰입도도 높아서 엄청 재밌게 봤습니다! 영화관 차이인지 저는 대사 엄청 잘 들렸어요!', '10']
# ['노웨어 스페셜', '그냥 계속 마음이 아팠어요 아들이랑 아버지의 감동과 어쩔 수 없는 슬픔을 보여주려는 게 너무 잘 보였고 너무 열린 결말? 어쩌면 다 알고 있을 결말로 끝나서 조금은 아쉽지만 그래도 너무 좋았어요!', '10']
# ['돈 룩 업', '누가 하늘을 보았다하였는가. 천문학 잘 모르는데도 완전 재밌게 봤어요', '10']
# ['씽2게더', '너무  기분  좋아요 다시 보고싶어요    미치겠어요', '10']
# ['경관의 피', '이정도면 볼만하고 재미있어요 관객수준이 평론가 급인가 ㅎ ㅎ 남자영화', '10']
# ['경관의 피', '이해도 안되고 재미도 없는 망작. 조진웅 박희순의 연기는 10점이나 최우식의 발연기와 노잼 스토리가 최악이라 별점 하나 드립니다.', '2']
# ['노웨어 스페셜', '네가 내리쬐는 햇빛 속에 있을 때, 퍼붓는 빗속에 서 있을 때, 네 곁에 내가 있을 거야. 네가 포도를 먹을 때, 포도의 맛 속에 내가 있을 거야.', '8']
# ['통증', '천하의 권상우가 왜이렇게 혓바닥이 길어?', '10']
# ['기적', '매력적인 연기자들, 반전 그리고 유쾌하면서도 감동적인 뻔하지만 눈물 흘릴 수밖에 없는 따뜻한 영화', '10']
# ['나를 찾아줘', '작위적이고 과한 설정때문에 몰입이 방해된다', '6']
# ['씽2게더', '다 나온 노래들이 한번쯤 들어본 노래여서 좋았다', '10']
# ['씽2게더', '대박이에요 1보다 더 재밌음!!ㅠㅠ 꼭 보세요', '10']
# ['장르만 로맨스', '웃을일이 없는데 간만에 웃으며 재미있게 잘 봤습니다. 이런 영화 또 만들어주세요', '10']
# ['아바타', '설렜다', '9']
# ['혼자 사는 사람들', '여운이 오래가요 위로되었어요', '10']
# ['경관의 피', '배우들의 합이 좋네요! 조진웅은 말할 것도 없고 최우식의 연기변신이 돋보입니다. 믿보배 등극!!^^ 영화 재밌게 봤습니다.', '10']
# ['후궁 : 제왕의 첩', '대비 머리가 너무 거북스럽고 궁이 조선시대 양식이 아닌 것도 거북스럽고 이렇게 연출한 이유가 뭘까 의문스럽고 외국에서 어떻게 한국을 이해하게될지 걱정스럽다. 내용이 괜찮은 것같은데 일이 왜 이렇게 되었는지ㅠㅠ', '5']
# ['칠드런 액트', '종교는 나약한 인간을 지탱해줄 구원의 밧줄인가 아님 인간을 더욱 나약하게 만드는 믿음의 족쇄인가 사람은 자신의 마음을 표현해내기위한 어떠한 선택을한다 그 선택은 진실과 거짓보다도 앞선 자유로움에 기대고싶어하는 자신의 믿음이기 때문이다.', '10']
# ['연애 빠진 로맨스', '요즘도 잡지 보는 사람이 있나?', '2']
# ['로건', '아이언맨 스파이더맨 다 필요없습니다.제 평생의 히어로입니다.', '10']
# ['승리호', '예전 서태지와 아이들 처음 나왔을때 그 감동이네~~~헐리웃 저리가라!', '10']
# ['여타짜', '호기심에 봤더니 역시나....중간까지라도 본 내자신이 대견하네...병원에서 머리짧은사람은 그렇다 치고 이채영은 맥락없이 왜벗는거지? ㅈㄴ뿜었네ㅋㅋ 연기가 안되니까 몸빵하는거냐 이건 뭐...삼류라는말도 아깝고 그냥 쓰레기네', '2']
# ['스파이더맨: 노 웨이 홈', '보면서 질질 짰어요....', '10']
# ['위플래쉬', '이런 광기를 보고 열정을 입에 담는 정신 나간 세상.', '10']
# ['킹스맨: 퍼스트 에이전트', '진짜진짜진짜 영화관 뛰쳐나온적은 처음이네요살면서 이렇게 ㅈ그지같은 영화는 본적이없는데 하 욕밖에안나오고 어지간하면 킬링타임 뇌놓고보는영화 라고 커버치는데 이건 ㅋ진짜 시간아까우니까 절대보지마세요 기분개잡침 킹스맨 1 2  기대하고가면 미친놈됨', '2']
# ['해피 뉴 이어', '너무 재밌게 봤다 화려한CG에 울리는사운드의 마블영화보다 감성정인 이 영화가 훨씬 낫다.평점 8.8', '10']
# ['씽2게더', '더빙으로 먼저 본뒤 이건 무조건 원본 자막으로 봐야겠구나 싶어 두번을 보았는데, 두번째가 더 전율을 느끼며 재미있었다. 그냥 다 좋다. 특히 고릴라 춤볼 때 전율+감동..동물들을 캐릭터로 한 게 참 인상적이다. 이영화 애들 영화 아니니 무조건 보며 즐기세요!', '10']
# ['드라이브 마이 카', '이거슨 증말 좋은 영화다 ㅇㅇ', '10']
# ['경관의 피', '내 인생 최악의 영화 홀리쉿', '1']
# ['씽2게더', '뮤지컬풍으로 바꾼 노선과 새로운 캐릭터 클레이의 등장으로 기대감은 한층 높였지만 스토리상 보여줄게 너무 많아서 하나하나에는 집중하지 못한 것 같은 느낌이 들었기 때문에 다소 아쉬운 작품', '7']
# ['레드 노티스', '킬링타임용으로 제격 ...가볍게보기 잼나네요', '7']
# ['씽2게더', '노잼 ……. 디즈니 영화 다 좋아하는데 이 작품 실망했어요 진심 중간에 집갈 뻔함  영상미 때문에 6점..', '6']
# ['씽2게더', '아이들이 좋아했어요!!!!노래도 넘좋고 더빙판 봤지만 괜찮네요', '10']
# ['고스트버스터즈 라이즈', '감독은 이렇게 찍어 놓고도 돈받나?뭐이런 중꿔 갬성 c급 영화를 봤나..', '2']
# ['맨 인 블랙: 인터내셔널', '음… 주인공 매력으로 찍은 영화', '6']
# ['너에게 가는 길', '내 옆에 사람의 일이라고 생각한다면 조금은 더 이해할 수 있지 않을까 하는 생각을 했습니다. 물론 우리가 이해를 하고 하지 않고의 문제는 아니지만 서로에게 상처를 주거나 하지 않았으면 하는 바람입니다. 모르던 이야기들을 알게 되어 뜻깊은 영화였어요', '10']
# ['극장판 소드 아트 온라인 -프로그레시브- 별 없는 밤의 아리아', '소아온 1~2화의 명품 리메이크 & 리부트', '9']
# ['도가니', '이게 실화라고? 헐.. 장애아동들에게 이런 악한 짓을 하다니.. OOOO새기들 모두 지옥으로 떨어지기를..', '10']
# ['씽2게더', '너무 잼있어요..1편보다 더', '10']
# ['베놈 2: 렛 데어 비 카니지', '뭔가 빨리 끝나는 느낌  쿠키영상은 대박이다', '8']
# ['스파이더맨: 노 웨이 홈', '스파이더맨이 어려서 사고무탁한 점을 감안한다면 충분히 재밌는 영화입니다.', '7']
# ['경관의 피', '배우들의  탁월한 연기  탄탄스토리 넘 잼나게 시간가는줄 모르고 봤네요', '9']
# ['스푸키즈 극장판 비밀과외', '아이가 정말 좋아하네요!!제가 봐도 재밌어요!', '10']
# ['드라이브 마이 카', '상실의 아픔을 제대로 들여다보는 것. 그리고 삶을 살아내는 것. 이 작품을 통해 영화가 가진 힘을 다시 한 번 느낀다.', '8']
# ['어벤져스: 엔드게임', '와 평점 봐...와우 대박!', '10']
# ['정복자 펠레', '우리는 아직 농장에 서 있다', '10']
# ['밍크코트', '나는 감히 누굴 탓할수있을까요..ㅠ오랜만에 가슴저미면서도 한참을 생각하게되는 영화네요..황정민씨연기도 훌륭합니다', '10']
# ['샹치와 텐 링즈의 전설', '국민 배우 배도환님 주연', '4']
# ['더 플랫폼', '공산주의와 자본주의 둘다 정답은 아니다 그렇지만 차악을 고르라면 자본주의가 더 나은 선택인게 현실이다 이 영화는 전 세계가 양극화가 심화된 오늘날 우리에게 주는 경고가 아닌가싶다 만약 미래에 자본주의가 무너진다면 그다음에는 어떤 방식으로 새로운 이념이 나올까? 그이념도 처음에는 좋은 방향이겠지만 그 끝은 참혹하지않을까 생각해본다 조지 오웰의 동물농장 처럼', '9']
# ['유체이탈자', '처음엔 뭔얘기야? 했는데  재미있네요. 윤계상 연기가 넘좋아요.', '8']
# ['경관의 피', '배우에 돈을 다 썼는지 마이크가 잘 안되더라구요', '6']
# ['우는 남자', '아쉬운 점이 있지만, 액션 좋고, 스토리도 이만하면 나쁘지 않고, 몰입감도 좋았으며, 죽은아이 영상보면서 오열하는 김민희 연기도 좋았음. 평가절하되어 있지만 이만하면 충분히 좋은 작품임.', '8']
# ['범죄와의 전쟁 : 나쁜놈들 전성시대', '연못에 미꾸라지를 두지않는 이유', '9']
# ['강릉', '시간이  아까웠어요 ㅋㅋ ㅡㅡ돈아깝고', '2']
# ['해피 뉴 이어', '연말 영화의 정석. 오히려 뻔하고 변화구 없어서 좋았다. 모두의 사랑이 이루어지기를', '6']
# ['해피 뉴 이어', '엽기적인 그녀, 클래식 감독 맞으시죠..?', '2']
# ['경관의 피', '오랜만에 재밌었어요.누가 선이고 누가 악인가?', '9']
# ['씽2게더', '잘봤어요', '8']
# ['타이거테일', '드는 폼은 나쁘지 않았다 무게가 엉성했을뿐', '6']
# ['경관의 피', '잘봤어요', '8']
# ['레이디스 나잇', '행오버 좋아하면 무조건 좋아할듯 존잼ㅠㅠㅎㅎ', '10']
# ['경관의 피', '내용은 중구난방에 연출이나 사운드는 너무 올드해서 2022년에 개봉한 영화가 맞나싶음. 개인적으로 기대하고 본 영화였으나 매우 실망함.', '1']
# ['맨 인 블랙: 인터내셔널', '재밌었는데..다들 난리지', '10']
# ['말모이', '살면서 당연한듯 쓰였던 우리말들을 곱씹게하는 영화', '9']
# ['사라진 시간', '절대 가볍게 농담으로 치부할 영화 아님.  아 나는 이 영화의 진지함에 반했다~~!', '9']
# ['해피 뉴 이어', '배우들보러 갔어요~ 가볍게 보기 좋습니다ㅎ사실 영화관에서 돈 주고 보가는 아쉬워요…티빙에서 보세요ㅋㅋㅋ', '8']
# ['로스트 인 더스트', '먼지 가득한 텍사스를 그리고 있지만, 모든 것이 깔끔한 수작.', '8']
# ['걸캅스', '호에에에~걍도가 캴 들었쪄여~후미밍ㅜㅜ~더망ㅎ~피의자 사망~동료 선배옵햐 고마워연♡위기탈출 남봉원~', '1']
# ['킹스맨: 퍼스트 에이전트', '진지한 킹스맨 재밌다', '9']
# ['씽2게더', '스토리적으론 1편보단 아쉽지만 눈과 귀는 더 황홀해짐. 팝이 많이 나옴.', '8']
# ['요요현상', '요요인으로서 와닿는 내용이였구요 진로에 도움이 많이 되었습니다', '10']
# ['매트릭스: 리저렉션', '당시 충격적이었던 감동만큼은 못하지만 그 추억을 가진 사람에게는 추억을 리마인드해주는 것만으로도 뜻깊다.', '7']
# ['조작된 도시', '내가본게 만환지..영환지..', '1']
# ['스카이 하이', '70년대 영화라고 해도 잘 만들었다. 출연진도 좋고', '7']
# ['조작된 도시', '평점 너무 과하다ㅠㅠ개봉당시 난 만화영화 한편 보고 나온거같았다ㅠㅠ', '6']
# ['매트릭스: 리저렉션', '큰 기대를 하지 않았는데 그것보다 더 큰 실망을 했습니다. 매트릭스 팬으로서 많이 아쉬웠네요.', '3']
# ['스카이포스 3D', '애들이 보기엔 딱 이다..', '6']
# ['해피 뉴 이어', '유치함의 끝으로 첫장면을 시작하더니 갈수록 더하네요. 보다가 껐어요. 이렇게 유치한 영화는 처음이에요', '2']
# ['영웅: 샐러멘더의 비밀', '김보성 형님이시다. 더이상 자세한 설명은 생략한다', '10']
# ['극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들', '재미있는데 감동주기 쉽지 않아요.클라이맥스에서 슬픈데 3초후에는 너무 웃겨서 웃엇어요...진짜 잼잇음 옛날 짱구감성 나서 좋앗어요', '10']
# ['스카이파이어', 'cg 기술은 많이 발전했네..  스토리가 너무나도 올드하다', '4']
# ['스파이더맨: 노 웨이 홈', '극장가서 두번 보는 영화는 추적자 이후 처음… 왤케 난 눈물이.. 너무 재미있는데 눈물도 나요..', '10']
# ['악마를 보았다', '10년전 영화 처음 나왔을때 한번 보고 그이후 넷플릭스 떳길래 한번더 봤슴. 그때는 몰랐는데 지금 다시보니 이수현(이병헌)이 조나 병의신짓을 해서 애꿎은 피해자들만 더발생했네...지금 다시봐도 최민식의 사이코 연기는 진짜 혀를 내두를 정도다.', '7']
# ['해피 뉴 이어', '멀티캐스팅이 돋보이는 뻔한 옴니버스 로맨스 영화.', '7']
# ['유체이탈자', '정신없어요 정신없는데 잣어요', '4']
# ['경관의 피', '그냥 저냥한 경찰 범죄 오락 영화. 조진웅 배우가 돋보임.', '6']
# ['크림', '시련의 아픔을 달콤한 크림(음식)과 소중한 사람들과의 인연으로 함께...극복하는 스토리일 줄 알았는데 알록달록 화려한 색감의 디저트들이 예상했던 것보다 비중(?)이 적다...조숙하고 당돌한 소년 ㅎㅎ 근데 묘하게 풍기던 중국풍스러운...??', '6']
# ['킹스맨: 퍼스트 에이전트', '시초를 알수있기는하나 킹스맨이 이끌어가던 스토리와는 거리가먼듯한느낌이예요 너무 기대를한탓일까요 간단명료한 스토리에 섹시미잇는액션미가 좋앗던건데 이번시리즈는 좀아쉽습니다 아들이 암존재로 나오는것도 한몫햇고요킹스맨을기다렷던 때로 돌아가고싶네요', '4']
# ['푸른 호수', '우리 모두가 꼭 봐야 할 영화라고 생각합니다. 정체성의 혼란, 어느 나라에도 속할 수 없는 외로움 그러면서도 떠오르는 친모와 자신이 태어난 나라에 대한 아련한 그리움과 동경 ....의붓딸을 바라보며 자신과 오버랩 되는 감정과 시선,  사랑, 아직도 마지막 장면이 잊혀지지 앟습니다. 이 영화는 많이들 봐주셨으면 하는 바램이있네요', '10']
# ['킹스맨: 퍼스트 에이전트', '킹스맨 에이전시의 기원을 다룬 편이라는 데에 의의를 둬야 합니다.', '8']
# ['다만 악에서 구하소서', '황정민을 꼭 죽였어야 했나 . 아이가 정신병 안걸리면 다행', '6']
# ['조작된 도시', '별 생각없이 관람했는데 와~~ 정말 신세계배우들 연기짱', '10']
# ['스파이더맨: 노 웨이 홈', '너무 재미 있었어요 스포가 될까봐 말은 못하지만, 이번에 나온 스파이더맨과 빌런들을 개인적으로 많이 아낍니다. 정말 재미 있었고 개 추천이니까 꼭 보세요 다음에 닥터 스트레인지 영화와도 연결된데요!!', '8']
# ['나이브스 아웃', '진짜 재밌었음.. 결말이 너무 딱딱 들어맞는 퍼즐조각 같아서 좀 허무하긴했지만 쫄깃쫄깃한 추리극이라 재밌었음ㅎㅎ 제임스본드 아저씨가 탐정으로 나오는데 멋있어용 짱재밌다ㅠㅠ 2편 안나오나', '10']
# ['매트릭스: 리저렉션', '시간낭비 제작비 낭비 인생낭비언제적 매트릭스냐진부한 일본감성도 역겹다키아누 리브스는 일본을 참 좋아하나보다동반몰락 딱 어울리네', '2']
# ['아빠는 딸', '티비에 하길래 우연찮게 봤는데 너무 재밌네용ㅎ', '10']
# ['씽2게더', 'OST가 정말 너무너무 좋다! 배우들의 목소리 연기도 그 어느때보다도 최고였다! 3편 또 언제나오나 ㅜㅜ', '10']
# ['씽2게더', '방탄 노래가 나오다니 그것만으로도 아미는 충분했다', '10']
# ['해피 뉴 이어', '영화 개봉전부터 굉장히 기대하고 있었는데 생각보다 재미도 없고 연출이 좀 부족한거 같아요.근데 배우들이 다 유명한 배우분들이셔서 배우분들 보는 재미는 있는거 같고,저는 개인적으로 이강이 상훈에게 새 차키를 주며 대화하는 장면과 상규가 눈을 맞는 장면이 감동적이었던거 같아요.그리고 세직이 아영에게 고백하는 장면도 학생들의 풋풋한 사랑 이야기를 담아서 좋았고,소진과 승효가 엘리베이터에서 대화를 하는 장면이 조금 안타깝고 슬펐어요.그런데 거기서 끝났다면 아쉬웠겠지만 진호가 선을 보자는 대화를 하는 장면이 들어가서 좋았던거 같아요.용진과 이영의 사랑 내용은 좀 너무 빠르고 급한 느낌이 들어서 별로였어요.그리고 수연이 나오는 장면이 너무 적어서 특별 출연인줄 알았어요.그리고 재용이 호텔을 나가면 돈이 없을텐대 나가서 어떻게 사는지 어디서 사는지 그런 내용이 없어서 너무 궁금했어요.전체적으로 많이 아쉽고 뻔한 스토리긴 하지만 저는 일부로 뻔하게 스토리를 만들었다고 생각해요.연말에 가볍게 볼 수 있도록 만든 영화인거 같아요.저는 매년 연말마다 볼 거 같아요.', '7']
# ['크루엘라', '두 엠마의 명연을 볼수있었던 101마리 달마시안의 재해석,,조커,할리퀸과 결이 다른 디즈니판 사이키 연기등장,IP의 중요성을 인식함', '9']
# ['유체이탈자', '액션은 좋았지만 엔딩이 아쉬웠어요', '10']
# ['스파이더맨: 노 웨이 홈', '추억의 스파이더맨등장으로 넘 잼잇어요~', '10']
# ['황무지의 괴물', '너무 재미없어요   몰입감도 떨어지고 보는내내 지루해서 하품만 나네요  그나마  아역배우 연기가 좋아서  별2개 선택함', '4']
# ['소울', '엄청난 상상력과 세밀한 스토리. 하루하루 순간순간을 즐기고 아끼고 사랑하며 소중하게 여기기 다시 생각함', '9']
# ['가디언즈 오브 갤럭시 VOL. 2', '욘두ㅜㅠ 가오갤 3 존버합니다', '10']
# ['서핑 업', '다큐형식으로 이루어진 영화라 흥미로웠다스토리는..전형적이다그치만 서핑을 좋아하는 사람이라면 감정이입이 되면서 볼듯!', '9']
# ['비밀은 없다', '잠이안와 우연히 본 영화.평점이 넘 낮은거 아닌가!첫씬부터  손예진의 연기가 대충보고 자려고 했던 내 감성을 뒤흔들었다.지금은 고인이신 김주혁님의 연기또한 소름이며아역배우들 역시 최고다.연출과 음악또한 감성을 짜버린다.추천추천추천 하며~~~손예진 화이팅♡♡♡', '10']
# ['해리 포터와 아즈카반의 죄수', '재미있어요 7살 아이가 보는데 살짝 이해하기힘든부분이 있어 설명해주며 봤어요', '10']
# ['보조바퀴', '홍석우 배우님의 팬입니다. 영화를 보게 된 이유이구요. 되게 재밌는 스토리와 배우분들의 감칠맛나는 연기들의 조화가 새롭고 좋았습니다. 영화를 이렇게도 만들 수 있구나라는 생각을 갖게 해준 즐거운 영화였습니다. 추천해요!', '10']
# ['경관의 피', '조진웅 연기는 괜찮았으나, 영화의 내용 전개가 좀 아쉬웠슴.', '6']
# ['해리 포터와 비밀의 방', '비밀의방도 재미있게봤어요', '10']
# ['바람의 검심 최종장: 더 비기닝', '내가 본 일본 실사판영화중에 이게 젤 잘만들었음!!!몇번을봐도 안질린다', '10']
# ['스카페이스', '악행,아집,독선,집착, … 정점에 올라가기까지 험났하고 어려웠지만 내리막은 너무 허무하고 비참 그자체 짧게나마 세상을 가진 스카페이스 알파치노만의 카리스마 넘사벽', '8']
# ['해리 포터와 마법사의 돌', '아이랑 방학동안 보고있는데 너무 재밌어요', '10']
# ['킹스맨: 퍼스트 에이전트', '전작보단 별로였지만 그래도 액션 굿', '10']
# ['돈 룩 업', '마치 푸른거탑 재난편을 보는 것 같았다. 99%의 현실과 1%의 과장으로 이뤄진 코미디 영화.', '10']
# ['고양이에게 밥을 주지 마세요', '오늘도 고양이밥에 쥐약탔습니다. 칭찬해주세요.', '1']
# ['씽2게더', '마지막은 "올해의 20분"', '10']
# ['씽2게더', '눈뽕, 귀뽕, 웃음 유발ㅋㅋ, 청소 원숭이 귀여워용ㅎㅎ, 캐릭터들 다 개성있고 사랑스러움^^', '10']
# ['고스트버스터즈 라이즈', '곡진하고 충실하다. 기술적으로 더 해낼 수 있었음에도 1, 2편과의 톤을 맞추기 위해 애썼다. 배경을 뉴욕에서 오클라호마로 옮긴 것도 그런 맥락인 듯. 원년 멤버와 스펭글러가의 아이들이 함께해서 더 큰 감동을 줄 수 있었다. 속편이 기대된다.', '8']
# ['경관의 피', '한순간도 간장감을 잃지않는 3배우의 조합~', '7']
# ['경관의 피', '음향, 음악… 마이너스 주고 싶어… 시끄럽고 안 들리고', '8']
# ['씽2게더', '눈과 귀가 황홀해지는 영화!', '9']
# ['스파이더맨: 노 웨이 홈', '삼스 등장신이 볼 수 있어서 너무 좋', '9']
# ['해피 뉴 이어', '원래 우리나라 ㅂㅅ 평론가들이 고매한분들이라 우리나라영화발전에 기여한 부분도 있지만 이걸 다 5점을 주냐 지극히 연말영화 매끄럽게 잘 만들어냈다 수출용 영화에 원래이렇게 보는 영화인거다 불편하지하지않게 잘 봤다', '8']
# ['스파이더맨: 노 웨이 홈', '내용이 너무  혼란스럽고 몰입감 없네요', '2']
# ['캔디맨', '어렸을땐 무서웠는데..', '7']
# ['어드리프트:우리가 함께한 바다', '쉐일린 우들리 넘 예쁘고... 영화가 실화라서 그런지 참 매력적임...♡', '10']
# ['드라이브 마이 카', '차곡차곡 이야기를 쌓아가며 끝에가서야 터뜨리는 주인공들의 눈물이 감동적입니다.', '8']
# ['스파이더맨: 노 웨이 홈', '스파이더맨이 있어서 행복하다! 역대 스파이더맨이 한자리에 모였을때 개 감동 흑흑..;;;', '10']
# ['씽2게더', '씽1을 재밌게 봐서 기대하며 봤는데 스토리는 흔하지만 노래도좋고 너무 재밌고 행복했다ㅎ 추천!그리고 1안봐도 이해가능!', '10']
# ['널 기다리며', '심은경 연기 이상한 건 나만 그래? 이건 좀 다른가 싶어 봤더니 얘 때매 영화보다 짜증내는 거 올만이네.', '2']
# ['스파이더맨: 노 웨이 홈', '아직 인생은 살만합니다.', '10']
# ['퍼펙트 스트레인저', '완벽한타인 보고 원작 찾아봄. 복붙 안할수가 없네, 오리지널이 이렇게 탄탄한데 뭘 어떻게 고쳐 ㅎㅎ', '10']
# ['경관의 피', '둘의케미 생각보다좋다^^  너무잼있게봤습니다', '10']
# ['아멜리에', '환경도 중요하고 타고난 성격도 중요하다', '10']
# ['유체이탈자', '배우분들은 좋은데 진짜 역대급 노잼.. 내용 이해도 안돼고 클리셰 너무 따라가는 느낌이었어요', '5']
# ['스파이더맨: 노 웨이 홈', '최고의 작품을 봤네요 보는 내내 즐거웠습니다. 출연진 모두에게 감사히네요', '10']
# ['너의 이름은.', '내 살다살다 사이렌이 아름답게 들릴줄은 몰랐다', '10']
# ['씽2게더', '보고있으면 저절로 행복해지는 영화. 눈과 귀가 모두 즐거웠어요~', '10']
# ['보이스', '잼있었어요 ~ 보이스 피싱 항상 조심~', '7']
# ['회사원', '화려한 액션, 엉성한 총격전, 아쉬운 서사', '7']
# ['배트맨 대 슈퍼맨: 저스티스의 시작', 'DC 세계관을 이해하지 못 하면 이 영화를 이해하지도 못 하지', '9']
# ['오피셜 시크릿', '진실의 힘', '7']
# ['기적', '그냥 그럼 재미보다는 그냥 보는 영화', '2']
# ['듄', '최고의 sf', '10']
# ['돈 룩 업', '미국이 세계를 구하는 그런 뻔한 스토리가 아니였다는 점에서는 만족!', '7']
# ['킹스맨: 퍼스트 에이전트', '쓰레기영화,,,정말허접', '2']
# ['기적', '이성민씨 연기 진짜 잘하셔', '8']
# ['경관의 피', '조진웅이 멱살잡고 끌고 간 것 같았다… 최우식을 연기로 의심해본 적이 없었는데 이 역할이랑은 참 안어울렸던 것 같음… 특히 마지막 장면은 보면서 손발이 오그라들었다… 속편 예고 같은데 속편이 나올 일은 없을듯', '1']
# ['베네데타', '스토리가 충격적..', '8']
# ['스파이더맨: 노 웨이 홈', '오랜만에 다 보니 좋았습니다^^', '10']
# ['챔피언', '빈약 소재 못살린 연출', '2']
# ['엔칸토: 마법의 세계', '가볍게 봤는데 돌아서면 수많은 메세지를 느낄수 있는 영화', '10']
# ['경관의 피', '배우 연기나 그런 것은 좋았으나 전체적으로 긴장감이 좀 떨어지는 것 같아서 좀 아쉬웠습니다. 그래도 재미있게 봤습니다~', '7']
# ['갓파 쿠와 여름방학을', '진짜 너무 재밌게 본 애니메이션..재미만 있는게 아니라 감동도 있고 여러가지 생각을 할 수 있었던 애니메이션에요.어른들이 보면 더 감동할 애니..온 가족에게 추천했네요.  제가 좋아하는 일본의 아기자기한 풍경과 분위기. 그리고 너무 귀여운 쿠..', '10']
# ['판도라', '보면서 참 많이 울었던 영화네요. 원자력의 위험함은 모두가 알고 있지만, 자동차도 비행기도 처음에는 미흡한 기술력으로 많은 사고가 있었고, 그로인해 많은 생명을 잃었습니다. 하지만 그런 희생들과, 많은 분들의 노력으로 인해 현재는 어떻게 쓰냐에 따라 과거와는 비교할 수 없을 정도의 편의성을 얻었죠. 원자력도 마찬가지입니다. 위험하다고해서 그만두는게 아닌, 그 원료를 이용한 에너지는 무한하기때문에 추후에 더 좋은 기술력으로 후세가 얻게 될 세상은 더 나은 세상이 될 것이라 생각합니다. 경각심을 일깨워 주기에 좋은 영화라고 생각되네요.', '9']
# ['씽2게더', '너무 재미있게 시간 가는 줄 모르고 봤어요^^ 뮤지컬영화 좋아하시는 분들 꼭 보세요!', '10']
# ['고스트버스터즈', '확실히 우리나라 페미는 광기구나 이 영화 미국에서 완전 쫄딱망해가지고 감독도 짤리고 제작사 사장까지 짤려가지고, 후속작은 아예 원작만든 감독이 발벗고 나서서 찍었는데 근데 한국평점만 7점이 넘는다는게 참...조선시대가 쉐도우승리하다가 처참하게 식민지화 됐다는걸 잊었나?', '2']
# ['여타짜', '…..스토리도 실망 ㅠㅠ 너무 영화가 실망 ㅠ', '4']
# ['해피 뉴 이어', '별로,,, 재미 없어요,,,, 영화만 집중해서 보는 게 어려워서, 일기 쓸 때 틀어놓고 조금씩 봤네요ㅠㅠㅠ 좋아하는 배우들이 많이 나와서 기대를 많이 했지만, 영화를 보고 무엇 하나 마음에 남은 게 없어서 아쉽네요,,ㅠㅠㅠㅠ 더 좋은 영화가 나오면 좋겠네요!', '2']
# ['램', '독특한 영화였습니다', '6']
# ['솔저 발터', '정답이 없는 전쟁의 허무함', '10']
# ['남산의 부장들', '이성민 배우님 박통이랑 싱크로율이 굉장히 높아서 더 몰입해서 볼 수 있었습니다. 그 날의 역사를 더 자세히 알게 되었네요. 앞으로도 이런 영화를 많이 볼 수 있길 바랍니다.', '8']
# ['클라우드 아틀라스', '와 이걸 이제 봤네  명작ㄷㄷ', '10']
# ['노웨어 스페셜', '너무나도 슬픈 상황을 담담하게 풀어 더 슬픈..', '8']
# ['아이', '내가 도와 줄께요...진짜 감동 받았습니다.', '7']
# ['씽2게더', '귀호강 & 쉴 새 없이 흥겨움', '10']
# ['경계선', '인간이 정의한 경계선에 대한 반성', '7']
# ['스파이더맨: 노 웨이 홈', '마블 영화는 역시 유치해', '2']
# ['스파이더맨: 노 웨이 홈', '3 SPIDERMAN 삼스파 삼파이더맨 3 스파이더맨', '10']
# ['1987', '인생 최고의영화..  가슴이 뜨거워지는 영화', '10']
# ['아사코', '차분하고 진득하게 인물과 감정을 바라보는, 기다려줄 줄 아는 촬영이 굉장히 인상적이었습니다. 어느 영화에선가 봤을 법한 이야기인데도 더없이 몰입이 됩니다. 간만에 진짜라고 부를 수 있을 일본 감독의 출현이네요.', '10']
# ['씽2게더', '재밌네.. 사실 나는 씹덕이 아니었을까', '9']
# ['경관의 피', '뭐라는지 잘 안들리고 그냥 양산영화 같음', '2']
# ['숏버스 배우행', '재밌는 단편 영화들을 볼 수 있었습니다', '7']
# ['경관의 피', '완전 재밌음!조진웅 최고!', '10']
# ['씽2게더', '아는 노래 나올 때 마다 부르고 싶었다,,휴', '8']
# ['노웨어 스페셜', '덤덤해서 슬펐어요', '7']
# ['경관의 피', '규만이 또 찍었니? 이번에도 마누라가 피디하고?', '1']
# ['돈 룩 업', '명작이다. 정말 여러가지 복잡한 생각들이 든다. 지구가 얼마나 소중한곳인지, 우리가 얼마나 복잡한 세상에서 살고있는지, 우리모두가 더 대화하고 협력하고 답을 찾기위해서 서로 믿어야한다. 인류를 위해 헌신한 과학자들에게 박수를 보내고싶다. 이 영화를 지구를 더 아끼고 소중하게 생각하게 만든다.', '10']
# ['돈 룩 업', '배우들 코믹연기가 인상 깊었음', '10']
# ['경관의 피', '조진중 최우식 박희순....배우들 연기 볼만 했음!! 근디 사운드 믹싱이 잘못 되었는디 대사가 잘 안들리네요....별 하나 마이너스', '6']
# ['돈 룩 업', '일단 캐스팅으로 죽여주고 그 다음은 메시지의 당위성', '8']
# ['소리도 없이', '올해 최고영화.예상을 뒤엎는 전개유아인과 유재명의 연기도 최고', '10']
# ['할로윈 킬즈', '이런 한심한 코미디영화를 돈주고 봤다는 사실에서 난 살해당해야한다', '1']
# ['전설의 라이타', '약간 진부하지만 재미있게봤습니다.라~이~타파이팅!!!', '8']
# ['브라더', '초반부 창고에서 빈 종이 상자 맞고 기절하는 양아치들 보고 바로 손절…격투장면도 존나 엉성 이딴 쓰레기영화에 투자한 내 10여분이 존나 아깝고 억울함', '1']
# ['건축학개론', '영화가 끝난 후에도 마음은 계속 캠퍼스에 머물렀던...', '8']
# ['킹스맨: 퍼스트 에이전트', '싸움씬은 다 조앗어여', '2']
# ['말리그넌트', '반전이나 액션이 재밌는 추천작', '8']
# ['킹스맨: 퍼스트 에이전트', '정말 최악의 영화중 하나였습니다', '1']
# ['로리타', '너무나 인간적이고 아름다운 영화였다', '10']
# ['해피 뉴 이어', '배우의 팬이다, 배우의 얼굴을 큰 화면으로 감상하고 싶다, 애기부터 할머니할아버지까지 단체로 영화를 보러간다 하시는 분들만 보세요~~~~옛날 로맨스 영화로만 연애를 배운 사람이 나름대로 전연령을 대상으로 하겠다며 되지도 않는 서사 이리저리 구겨넣은 것 마냥 감동도 재미도 없이 배우 얼굴만 기억에 남는 영화가 됐음ㅠㅠㅠㅠ', '3']
# ['스파이더맨: 노 웨이 홈', '마블빠들 수듄임니다^^ 정상적인, 객관적인 시야에서 영화를 내다보세요. 일반인들은 세뇌안되어서 이런 전개 역겨워서 척추가 요동칩니다', '1']
# ['씽2게더', '기대 이상의 속편', '8']
# ['엔칸토: 마법의 세계', '너무 재밌어서 다섯번봄', '10']
# ['경관의 피', '기대안했는데 시간가는줄 모르고 봄 오랜만에 쫀쫀한 한국영화 극장에서 보니 좋았음', '9']
# ['경관의 피', '박희순 배우 대사 전달력 안 좋았다는 점은 인정. 다만 배우들의 탄탄한 연기력을 바탕으로 보는 내내 박진감 있고 집중도 높았던 영화는 맞다. 대사를 이유로 영화 자체가 평점 6,7점 받을 영화는 절대 아님', '9']
# ['라라랜드', '감히 찬사를 할 수 없는 명작!', '10']
# ['퍼펙트맨', '조진웅 부산 깡패 연기 너무 잘함. 재밌음', '8']
# ['라라랜드', '축구도 잘하고 연기도 잘하는 해리 케인! 엠마 왓슨도 굿~', '10']
# ['스파이더맨: 노 웨이 홈', '진짜..존잼이었다슾디좋아하는사람이면 백이면백 재밌을영화', '10']
# ['경관의 피', '진지한 투캅스 재미없어요', '6']
# ['킹스맨: 퍼스트 에이전트', '재밌음... 기대안햇는데 재밌엇다', '10']
# ['경관의 피', '최우식 필모 중 가장 안맞은 역할 같다. 느와르 버전 투캅스 같은데 러닝타임에 맞춰 너무 이런저런 이야기를 쑤셔넣은 기분이다. 그리고 난 다른 평에 비해 대사는 잘 들렸음.', '5']
# ['씽2게더', '진짜 노래 너무좋다 이야기와 노래둘다 너무좋았다', '10']
# ['스파이더맨: 노 웨이 홈', '과거를 그리워할수 있는 영화', '9']
# ['매트릭스: 리저렉션', '김보성 형님의 의리로 끝까지 봤다. 김보성형님께 감사드려라.', '6']
# ['라디오 스타', '인생에 터닝포인트..나에게도 인생의 터닝포인트가 올까', '10']
# ['장르만 로맨스', '천만이 넘어야 할 영환데.. 짱깨 바이러스가 원망스러울뿐..', '10']
# ['뮬란', '재밌었음로맨스 안 끼워넣은 선택이 참 탁월하다', '10']
# ['매트릭스: 리저렉션', '튜닝의 끝은 순정이다. 그렇다.', '6']
# ['블라인드 사이드', '산드라 블록이기에 풍성해질 수 있었던 영화', '8']
# ['씽2게더', '내가 본 애니메이션영화중 최고였다', '10']
# ['도라에몽: 스탠바이미 2', '진짜 펑펑울면서 봤어요ㅠㅠ1년간 흘릴눈물 다 흘렸네요ㅠㅠㅠ', '10']
# ['악녀', 'ㅋㅋ무슨 여자가 천하무적이가', '1']
# ['씽2게더', '너무 재미있게 봤어요제 최애 영화 입니다시즌2를 만들면 1보다 좋기는 어려운데 이건 더 재미있네요 ??', '10']
# ['스파이더맨: 노 웨이 홈', '엔드게임 급으로 추천.. 보면서 몇번이나 울컥했네ㅜㅜ', '10']
# ['킹스맨: 퍼스트 에이전트', '주인공 아재. 007에 나왔었는데 멋지네요. 아들 나오면 몰입감떨어지고 아빠나오면 몰입감오르는 상황', '8']
# ['라스트 나잇 인 소호', '초반부는 엘리의 런던 적응기, 중반부는 미스테리, 후반부에 이르러서야 스릴러가 급박하게 몰아치는 전개 구조라서 장르가 혼란스럽고 줄거리를 정신사납게 느끼시는 분들도 있을 것 같습니다. 결말부에 반전이 있기 때문에, 그 답(샌디를 죽인 범인은 누구인가?)을 탐정이 돼서(엘리와 함께) 찾아보는 재미가 있는 영화라고 생각합니다. 개인적으로 소재와 서사의 참신함보다는 연출, 영상미, 음악에 좀 더 무게를 싣고 싶습니다.', '8']
# ['스파이더맨: 노 웨이 홈', '미국 마블 시리즈  정말 안본다 하면서  볼게 없어 보다가  잠들었다', '2']
# ['경관의 피', '잼있음.연기 너무 잘함', '10']
# ['랑종', '공포 말고 좀비영화라고 생각하고 봤으면 재밌다 생각했을거 같음', '6']
# ['매트릭스: 리저렉션', '진짜 너무 실망스러웠어..', '2']
# ['김복동', '진실에 눈뜨길..선동 거짓에 너무 난무하는 한국..', '1']
# ['미스 슬로운', '폭탄이 터지고 총칼이 난무하지 않아도 정치 로비라는 게 살벌한 전쟁과 같다라는 걸 아주 멋지게 풀어낸 작품입니다. 여주의 일에 대한 집착의 원인을 어린 시절 개인적 트라우마로 풀어나가지 않은 점을 높이 사고 싶네요.', '10']
# ['스파이더맨: 노 웨이 홈', '스파이더맨 어셈블! 역시 마블다운 영화였다', '10']
# ['유체이탈자', '뭔가 빈 느낌이 계속 든다', '5']
# ['부탁 하나만 들어줘', '블레이크 라이블리 넘나 좋아하는데 이런 연기도 하다니 역시 멋진 배우네요여운이 남는 영화였어요', '10']
# ['킹스맨: 퍼스트 에이전트', '또한번 해낸 매튜본! 액션이 정말 쩐다!', '10']
# ['더 임파서블', '재난을 격은 가족의 슬픔이 잘 느껴지네요ㅠㅠ', '10']
# ['사막을 건너 호수를 지나', '지독하다 지독해...', '1']
# ['씽2게더', '씽2 진짜 재밌어요!!!', '10']
# ['킹스맨: 퍼스트 에이전트', '나름 재밌었습니다 영국 엑센트 좋네요', '8']
# ['스파이더맨: 노 웨이 홈', '삼파이더맨 너무 좋았습니다', '9']
# ['스파이더맨: 노 웨이 홈', '스파이더맨이 스파이더맨 했다', '6']
# ['엔칸토: 마법의 세계', '심심할 때 보면 좋을 듯 재밌는데 약간 아쉬운 점이 있음', '9']
# ['씽2게더', '화려하고 노래도 좋고 재밌었습니다', '8']
# ['스파이더맨: 노 웨이 홈', '드디어 고등학교 졸업!', '8']
# ['고장난 론', '와....이거뭐죠...? 진짜 생각없이보다가 나홀로 눈물뚝뚝....', '10']
# ['해피 뉴 이어', '그냥 뻔한 내용..신데렐라 스토리', '2']
# ['경관의 피', '기대했는데 뻔한 내용..지루했네요', '2']
# ['보이스', '많은이들이 보고 이제는 당하지 않았으면...', '8']
# ['기적', '소름돋는 감동입니다. 정말 잘 봤습니다. 믿고 보는 배우님들이네요!! 추천합니다', '10']
# ['돈 룩 업', '한국이 많이언급돼 한국의위상이 높아져있음을 알게해준영화', '10']
# ['해피 뉴 이어', '가족들끼리 봐도 좋은 영화. 지루하게 느낄수 있으나 힐링영화로 좋아요:)', '10']
# ['스파이더맨: 노 웨이 홈', '놓쳐서는 안되는 장면이 너무 많은 영화', '10']
# ['씽2게더', '고릴라 춤대결해서 긴코원숭이 선생 이길때 울컥하고 그 외는 그냥 그럼. 특히 그 클레이 사자는 감동 무, 왜 거기 껴서 ㅡㅡ 들러리하는지 알수없음.', '6']
# ['봄날은 간다', '아날로그 테이프에 기록되는 인생과 사랑...바람결에 나부낀다.', '7']
# ['여타짜', '여배우들이 이뻐서 좋습니다', '8']
# ['극장판 바이올렛 에버가든', '눈물이 멈추질 않았습니다', '10']
# ['매트릭스: 리저렉션', '니오베를 한눈에 알아볼 시리즈 고인물이라면 좋은영화.', '9']
# ['콜', '전종서의 연기가 다했다... 시나리오 개연성 연출은 조금.. 아쉬움이 많다만 연기로 다 카바침', '10']
# ['콜', '배우들 연기력말고는 칭찬할만한게 하나도 없다. 시간 바닥에 버렸네..  내용,전개,결말...형편없다...', '2']
# ['캡틴 판타스틱', '주인공에게 감정 이입이 하나도 안돼 괴로웠다.. 이것도 아동학대의 일종임.. 한평생 어떻게 살지 전혀 선택권이 없던 자녀들이 딱하기만 했다. 아버지로부터 세뇌된 극단적 사상과 이론을 열살도 안 된 꼬마가 줄줄 읊어대는게 진정한 교육이 이뤄진 현장이란 말인가? 나이에 맞는 사회화 단계를 거치며 자기 주관을 세워나가는 공교육은 폄하하면서, 생존 훈련이랍시고 절벽을 타다가 뼈가 부러지기도 하는 교육은 삶에 이롭다고 생각하다니..농장에서 목가적으로 삶을 이어나가는 엔딩을 통해 이렇게 사는 가족도 있다..고 훈훈히 보여주고 싶었던 듯 한데, 여전히 아이들은 노동하고 학교엔 나가지 않으며 친구도 못사귄다. 그저 한 가족의 자유로운 삶을 추구할 권리로만 바라볼 건 아니다.', '7']
# ['해피 뉴 이어', '노잼 킬링타임도 안됨 시간 아까움', '1']
# ['8월의 크리스마스', '찡하게 가슴을 울리는 영화', '10']
# ['해피 아워', '하마구치 류스케의 설익은 작품이라 생각하지만, 그럼에도 압도적이다.', '9']
# ['하녀', '별로였음. 1점 주고싶은데 최저가 2점이라 2점드림.', '2']
# ['드라이브 마이 카', '두 남자 배우들이 차에서 스토리를 이어가며 연기하는 장면 너무 좋았고,이해하기 어려운 내용이긴 하지만 충분히 몰입 할수 있는 연출이 너무 좋았어요.', '8']
# ['셰이프 오브 워터: 사랑의 모양', '전 영화가 재미가 있든 없든 하나의 목표를 향해서만 가면 욕은 안하는 사람인데요 기분나쁘고 굳이 필요하지 않은 장면들이 너무 많습니다. 자위를 막는 씨리얼 대사,남자가 부인과 관계하는 장면, 엘라이자를 성희롱 하는 장면 등 이거 왜 넣었어요? 남성의 지위와 적대감은 꼭 성적인 무드로 만들어야하나요.. 감독들은 예술에 취해서 하나쯤 넣어야하나 생각하나본데 주제랑 안맞는 특이한 장면들 넣는거 진짜 별로입니다. 하나도 안멋있고 하나도 심오해보이지 않아요', '6']
# ['모가디슈', '이게 실화 바탕 영화지 ㄹㅇㅋㅋ', '10']
# ['스파이더맨: 노 웨이 홈', '이것 저것 많이 넣긴 했는데 그것을 잘 살리지 못한 것 같다. 영화를 보는 내내 지루함을 느꼈고 개인적으로 어벤져스의 문제점으로 생각하는 각 캐릭터의 밸런스 붕괴가 좀 많이 억지 처럼 느껴졌다. 그리고 왜 스파이더맨이 그렇게 빌런들을 살리기 위해서 그런 사고를 쳐야했는지도 잘 설득력 있게 다가오지 않았다. 전반적으로 이야기를 풀어가는 것이 흥미롭지 않고 지루해서 실망. 토비 맥과이어와 앤드류 가필드를 보고 시간이 참 많이 흘렀다는 것은 잘 느낄수 있었다.', '4']
# ['스파이더맨: 노 웨이 홈', '삼파이더맨이 모두 나왔는데 이렇게 심심할수가, 너무  많은걸 기대했었나 걍 잘못볶은 볶음밥같은 느낌은 나만 그럴까', '6']
# ['경관의 피', '영화에 기대가 너무 컸던 건지… 이해하기가 너무 어렵고 감동이 없음', '4']
# ['고스트버스터즈 라이즈', '개 쓰레기로 만들었누 ㅠㅠ', '2']
# ['인비저블 게스트', '봐도봐도 재밌어용ㅣㅣㅣㅣ', '9']
# ['어메이징 스파이더맨 2', '와우 어메이징스파이더맨2  완전좋았어요~~~그웬은 넘슬펐지만.', '10']
# ['매트릭스: 리저렉션', 'ㅁㅊ 완전 명작이구만 이거 재미없다는놈들은 전편 안보고이해력 딸림탁자거울에 비친 모습이며 완전 명작', '10']
# ['핵소 고지', '별 기대안하고 봤는데 최고의 영화. 전쟁영화스타일 안좋아하는데 이 영화는 한 인물 스토리에 집중되어있어서 이런 나도 보는내내 흥미롭고 감동스럽게 관람', '10']
# ['경관의 피', '대사가 잘 안 들려서 몰입감이 저해됨', '7']
# ['드라이브 마이 카', '잘봤어요', '10']
# ['경관의 피', '잘봤어요', '8']
# ['해피 뉴 이어', '잘봤어요', '8']
# ['경관의 피', '조진웅씨 엄청 멋있음 ㅠㅠ 연기도 잘하고 우식씨도 연기 잘하고 다들 너무 연기짱', '8']
# ['씽2게더', '스토리는 살짝 아쉬운데 귀는 즐거웠음', '7']
# ['클로이', '외로움이 사람을 다듬는 방식을 잘 보여준다.', '8']
# ['황무지의 괴물', '무슨말이 하고 싶었는지는 알겠는데, 풀어내는 과정이 엉망이랄까.', '5']
# ['소년시절의 너', '.', '10']
# ['스파이더맨: 노 웨이 홈', '캐스팅 띵작 이다 정말 최고', '10']
# ['스파이더맨: 노 웨이 홈', '캐스팅 띵작 이다 정말 최고', '10']
# ['프릭스', '완전 신선한 영화 다음회가 기대된다', '10']
# ['이터널스', '이거만든사람 진실의방으로', '1']
# ['가버나움', '당장 보시길 추천드립니다.', '10']
# ['스파이더맨: 노 웨이 홈', '정말 재밌게 잘 관람했습니다.', '10']
# ['스파이더맨: 노 웨이 홈', '쓰레기 영화 미국영화 식상함의 극치', '1']
# ['경관의 피', '영화가 소재는 재밌는데 예상대로 스토리 흐름이 뻔하네요 그리고 마지막에 마무리가 그렇게 될거라는 떡밥하나없이 가다가 후다닥 다 짜맞추는 그런 느낌이 조금 있었습니다 그래도 재미 있었어용ㅎ', '6']
# ['위대한 쇼맨', '몇 번을 봐도 볼 때 마다 감동받는 영화. 힘들 때 꼭 찾게되는 영화 중 하나', '10']
# ['쥬만지: 새로운 세계', '겁나 재밌음!! 초반만 잘버티면 재미 , 감동 , 오글거림 , 웃김 등 다 볼수 있음', '10']
# ['씽2게더', '재밌었다정말재밌었다', '10']
# ['씽2게더', '자막단색기 죽이고싶다', '8']
# ['씽2게더', '6살, 초6 데리고 갔는데... 애들 보다 제가 더 신나서 박수치고, 같이 춤출뻔했어요~ 스토리는 늘 그렇듯 보다보면 대충 예상되지만 연출이며 다른면이 커버해서 지루한줄 모르고 흥분상태로 봤어요~ 어린이집에서 단체로 온 꼬맹이들은 "언제 끝나~ 심심해~"하며 투덜대다가도 깔깔거리며 다시 집중하고, 또 투덜대다가도 집중하고... 초6인 아들도 대개 재미있었다네요~ 춤과 노래를 좋아하는 애들은 100퍼 좋아할듯요~ ㅎㅎ', '10']
# ['씽2게더', '넘 잼있어요 강추 아이랑 잘봤어요', '10']
# ['스파이더맨: 노 웨이 홈', '그저 스파이더맨', '10']
# ['킹스맨: 퍼스트 에이전트', '킹스맨다운영화', '10']
# ['씽', '내 인생 최고의 음악 영화...', '9']
# ['스파이더맨: 노 웨이 홈', '정말 재밌게 잘 관람하였습니다.', '10']
# ['킹스맨: 퍼스트 에이전트', '정말 재밌게 잘 관람하였습니다.', '10']
# ['씽', '연말시즌만 되면 생각나는 영화내최애 씽', '10']
# ['씽2게더', '정말 재밌게 관람하였습니다.', '10']
# ['어메이징 스파이더맨 2', '어스파3 반드시 나와야 한다!', '10']
# ['킹스맨: 퍼스트 에이전트', '프리퀼이지만, 액션은 기대보다는 아쉬웠음', '6']
# ['킹스맨: 퍼스트 에이전트', '정말 재밌게 관람하였습니다.', '10']
# ['스파이더맨: 노 웨이 홈', '정말 재밌게 관람했습니다.', '10']
# ['박쥐', '100626[7]그냥 볼만하다고 할까. 좀 역겨운 영상미..|220107[7]특이한 연출.', '7']
# ['모가디슈', '여러모로 대작인 영화...우리나라에서 이런 영화가 나왔다는게 감격스러울 정도. 두고두고 봐도 될 영화', '10']
# ['씽2게더', '영상미와 화려함은 2편이 훨씬 좋아졌지만 개인적으로 스토리나 감동은 1편이 더 나았어요. 1편은 아이와 더빙으로 봐도 자막이 안 궁금했는데 2편은 자막도 꼭 봐야할 것 같아요. 너무 더빙이라.. ㅠㅠ', '9']
# ['여타짜', '예전에 보던 배우분들 오랜만에 영화에서 보니 반가웠고 편안하게 즐기면서 보기 좋았습니다.', '10']
# ['엔칸토: 마법의 세계', '생각지도 못하게 잘 관람했습니다.', '10']
# ['귀멸의 칼날: 주합회의·나비저택 편', '재밌게 정말 잘 관람하였습니다.', '10']
# ['매트릭스: 리저렉션', '정말 재밌게 관람하였습니다.', '10']
# ['스파이더맨: 노 웨이 홈', '정말 재밌게 잘 관람했습니다.', '10']
# ['태양은 움직이지 않는다', '일본 배우들 연기 진짜 어색하네. 머 졸업작품 찍는것도 아니고 왜 한국배우들 섰는지 이해가 가네.', '4']
# ['킹스맨: 퍼스트 에이전트', '정말 재밌게 잘 관람했습니다.', '10']
# ['여타짜', 'FM코인이 아직도 살아있구나? 라는 느낌을 주는 영화. 진짜 퉤퉤퉤퉤지들은 들고 일어나서 댓글 주작까지 하는데 정작 보는사람은 있나 몰라?', '1']
# ['씽2게더', '너무 재미있어요.강추', '10']
# ['달콤한 인생', '한국 느와르의 정점!!', '10']
# ['해적: 바다로 간 산적', '개그 연기도 좋고 나름 액션도 많이 있네요 ㅎㅎ', '10']
# ['스파이더맨: 노 웨이 홈', '어릴 때 추억이 새록새록', '10']
# ['취권 2', '성룡 액션영화의 최고정점을 찍은 영화', '10']
# ['경관의 피', '진짜 믿고보는 조진웅♡ 너무 섹시해요ㅜㅜ', '10']
# ['해피 뉴 이어', '한지민 윤아 얼굴보러 가는 영화', '10']
# ['트레이닝 데이', '연기 미쳤다....특히 마지막 정글에서 연기 압권', '10']
# ['스파이더맨: 노 웨이 홈', '최고다역시 재밌음 액션쩐다', '10']
# ['스파이더맨: 노 웨이 홈', '최고다역시 재밌음 액션쩐다', '10']
# ['레이니 데이 인 뉴욕', '음악과 티모시 그 외에는.. 그래도 음악이랑 분위기가 넘 좋았어요. 왠지 나중에도 생각나더라구요.', '10']
# ['해탄적일천', '질풍노도의 에드워드양.#왜 때문에 인생은 뜻대로 살아지지않는걸까.#그나저나 차암 비슷한점이 많은 나라야. 깜짝깜짝 놀란다니까.고령가 소년 살인사건과 하나 그리고 둘의 발화점.', '7']
# ['씽2게더', '뻔한 이야기지만, 남녀노소 할 것 없이 즐거운 시간을 시간을 선사해주는 흥겨운 애니메이션, 왠지 모르게 뭉클한 것은 왜일까', '9']
# ['매트릭스: 리저렉션', '아름다웠다. 너무나 아름다웠다. 그 철학적 깊이는 깊어졌고 더 평화로워졌고 더 아름다워졌다.나는 이 영화를 진심으로 사랑한다. 팬들을 위한 영화이고 매트릭스123에 대한 철학적 이해와 그 배경이 되는 철학적 영적 지식이 없다면 워쇼스키의 의도를 이해하기 어려울 수 있고 낮은 평점들은 그런 것들이 반영된 듯 싶다. 나는 너무나 이 영화를 사랑하고 고맙다.', '10']
# ['스파이더맨: 노 웨이 홈', '영화 스파이더맨을 꾸준히 봐온 사람이라면 울컥하게 되는 모먼트가 상당합니다', '10']
# ['스파이더맨: 뉴 유니버스', '기대없이 봤다가 시간가는줄모르게 재밌게 봤음', '8']
# ['스파이더맨: 노 웨이 홈', '시리즈 1부터 봐왔다면, 짠해지는 영화', '9']
# ['선생 김봉두', '그냥 잔잔한 그시절의 우리 시골학교의 모습', '10']
# ['해피 뉴 이어', '손발이 오글오글', '6']
# ['이장과 군수', 'ㅋㅋㅋㅋ차승원 똥지리는 장면만 봐도 뽕뽑긴함ㅋㅋㅋㅋ', '8']
# ['경관의 피', '평점 낮아서 볼까말까 하다 봤는데꿀잼', '10']
# ['킹스맨: 퍼스트 에이전트', '매 끝 순간마다 뭐지 하는 애매한 느낌....', '7']
# ['돈 룩 업', '이 영화가 이야기 하는 말은 돈룩업도 저스트룩업도 아닌 그냥 룩이다자극적인 미디어가 제시하는 흑백논리에 빠지지 말고 국제 문제를 지켜보고 주관을 갖고 생각하는 습관을 가져야한다.', '10']
# ['드라이브 마이 카', '3시간이 2시간처럼 느껴졌음 특히 프롤로그 부분, 그게 40분이였다니 놀랐음', '10']
# ['씽2게더', '너무 좋았어요. 넘 감동적 음악부터 스토리구성다시 또 보고 싶어요', '10']
# ['여타짜', '훌륭합니다! 기대 이상의 퀄리티!배우들의 연기가 아주 인상적입니다', '10']
# ['스파이더맨: 노 웨이 홈', '정말 애같은 이유로 찾아오는 위기에 조금 당황했지만 그게 오히려 어울렸다는 생각도 듭니다. 그 외엔 전반적으로 재밌었습니다.', '10']
# ['노웨어 스페셜', '영화보고 나오는데 눈물이 계속 흐른다...', '9']
# ['덩케르크', '전쟁터에 있는 군인들의 공포감이 잘 느껴졌다 죽음의 공포 ...', '10']
# ['경관의 피', '대사가 잘 안들린 부분과 속편 예고는 아쉬웠지만 재미있게 관람하였습니다 ㅎㅎ', '6']
# ['씽2게더', '노래들이 너무 좋고 중독성이 있는 노래들이고 노래들이 많이 좋아요 영화에서 나온 노래들이 차례대로 들으면 영화를 보는 기분이예요 차례대로 노래들을 들으면 좋아요 차례대로 노래들을 알고 싶네요', '10']
# ['피노키오', '원작의 내용을 고스란히 따라가는데, 우스꽝스럽고 기괴한 분장과 몇몇 오싹한 장면 그리고 헛웃음이 나는 유치한 전개 때문에 가족 영화이지만 가족들이랑 보기에 좋지 않을 것이다.', '4']
# ['귀멸의 칼날: 주합회의·나비저택 편', '“무한열차”로 가기 전 준비 단계에 해당하는 작품인데, 바로 이전에 나온 “나타구모산” 편에 비해 화려한 액션은 거의 없고 대신 일본 특유의 과장된 유머가 많아서 아쉽다.', '5']
# ['워터 릴리스', '아직 자신들이 원하는 욕망이 어떤 건지 제대로 알지 못해서 때때로 자신들의 마음이 아프고 다치기도 하지만 주체성을 가지고 행동하는 주인공들의 모습은 인상적이고 흥미롭다.', '6']
# ['센과 치히로의 행방불명', '제가 좋아하는 음악들었는데요ost가 너무좋아서 별표많이했어요', '10']
# ['해피 뉴 이어', '곽재용 감독만이 가지고있는 감성이 있어 오랜만에 기분까지 좋았습니다~', '10']
# ['쿵푸 허슬', '20번은 본거 같은데 또 보고 싶은 영화.이런 영화가 앞으로 또 나올 수 있을까', '10']
# ['해탄적일천', '소녀에서 독립적인 여성으로 성장한 자리의 이야기에 40년 가까이 지난 지금도 여전히 공감할 수 있는 건 10대부터 30대에 이르는 캐릭터의 내적 성장과 외양 변화를 완벽하게 선보인 배우 장애가 덕분이다.', '8']
# ['위대한 소원', '배꼽이 우주에 있는 영화', '10']
# ['킹스맨: 퍼스트 에이전트', '재밌는데 화려함 보다는 고급스러움이 느껴짐', '8']
# ['여타짜', '재미있어요연출짱 연기짱~!!', '10']
# ['경관의 피', '대사 전달력 너무 떨어지고요 특히 박희순배우 너무 대사가 안들려요 오디오 대체 어케하신건지ㅠ 그외에는 킬링타임용으로 좋아요', '7']
# ['기방도령', '웃다울고 정말 감명깊게 봤다.재미없다는놈들은 베토벤 월광소나타 듣고 아잠온다.임영웅 노래정도는 돼야지 이런놈들', '10']
# ['경관의 피', '이제 한참 재밌어질 구간에서 끝나는 게 아쉽 스토리를 앞구간을 줄이고 끝나는 타임을 좀더길게 만들지 후속작 만들려는건가', '7']
# ['기적', '재밌게봤습니다^^ㅎ', '9']
# ['레미제라블', '뮤지컬 무대에서 낯선 언어로 보는 것보다 자막과 함께 방안에서 즐길 수 있어 만족했어요.', '10']
# ['매트릭스: 리저렉션', '제발... 헐리우드에서 중국과 일본은 자본만 대라.... 억지로 중국인/일본인,중국문화/일본문화 끼워넣어3류 영화 만들지 말고....둘다 영화 뭣도 못만드는 나라인데... 왜 자꾸 어색하고 괴기스럽게 제작에 관여해서 영화를 3류를 만드냐... 주제를 모르는 넘들.. 하... 진자 짜증난다.', '4']
# ['동감', '나의 인생관을 변화시킨 몇 작품 중 하나.윤소은의 선택에 동감하진않을지라도 그 향기가 너무도 좋은 것은..', '10']
# ['경관의 피', '음향 무엇...? 대사가 잘 안들려요 그거 빼면 볼만은 하네요', '6']
# ['다만 악에서 구하소서', '황정민,이정재 무슨말이더필요할까', '10']
# ['씽2게더', 'n차 관람 예정! 노래 듣다 울컥울컥 하는데 다 보고 나면 기분 좋아지는 영화', '10']
# ['클레멘타인', '자꾸 망작이라고 하시는데 안보고 말하는 사람도 태반인듯 합니다직접 보시면 정말 띵작입니다.', '10']
# ['씽2게더', '1편보다 재미있는 영화 있네요. 재미 감동 음악 그래픽 모두 좋았음.. 요 근래본 영화 애니 중 제일 잼있었음..', '9']
# ['여타짜', '어.2.가.없.다.', '2']
# ['엔칸토: 마법의 세계', '재밌어요!!내용도 너무 좋았어요', '10']
# ['엔칸토: 마법의 세계', '재밌어요!!내용도 너무 좋았어요', '10']
# ['유체이탈자', '노숙자 박지환 핫도그 기억나는건 홈리스의 미친 연기력', '8']
# ['유열의 음악앨범', '영화 추천해요! 모든 계절에 잘 어울리는 영화입니다.', '10']
# ['경관의 피', '장난아ㅏ님 무조건 봐야함', '10']
# ['씽2게더', '엄청 재밌어욬ㅋㅋ ost에서 감동 너무 좋아하는 노래에서!', '10']
# ['씽', '명곡들주구장창듣고자란나에게는그냥쓰레기연기도없고스토리도허접하고명곡들로도배한만화영화일뿐임 명곡들안들어본어린분들에겐음악이주는감동이커서좋겠지만 나에겐그냥무성의한만화일뿐 겨울왕국처럼새로운음악이있는것도아니고 영화수준이미성년자대상인듯 2도나온다는데 자식사랑하는마음으로같이보시길 새로운걸창조하려는노력자체가안보여서평가라는걸할수있는가싶네', '1']
# ['레미제라블', '모든 것이 완벽한 영화', '10']
# ['여타짜', '정말 재미잇습니다. 추천', '10']
# ['엔칸토: 마법의 세계', '그녀의 능력은 가족을 하나로 만들어준다', '8']
# ['경관의 피', '정말 정말 잼있게 봤어요. 보면 절대 후회안할거예요.', '10']
# ['스파이더맨: 노 웨이 홈', '초반에 너무 지루해용 ㅠ', '2']
# ['예수는 역사다', '보려고 하지 않으면 아무것도 보이지 않는다. 인간의 한계를 인정하는 순간 보일 것이다.', '10']
# ['여타짜', 'sosososossosososo', '8']
# ['여타짜', '아니 감독이 우리한테 탄을먹이네ㅋㅋㅋ어디 실습과제준비물????하셨나요?', '1']
# ['경관의 피', '사운드,내용이...', '4']
# ['경관의 피', '이정도면 자막 깔아줘야하는거 아니냐 인간적으로', '6']
# ['용순', '이수경 배우 너무 매력적', '10']
# ['킹스맨: 퍼스트 에이전트', '에비말  안들으면  죽는다는 교훈은 좋은데...흐름이 비상식적 설정의 영화', '6']
# ['해피 뉴 이어', '배우들 보는맛에 봤다', '4']
# ['씽2게더', '너무 좋다 또 보러 갈 예정', '10']
# ['모가디슈', '너무 재밌고 감동이네요', '10']
# ['스파이더맨: 노 웨이 홈', '괜찮았다.', '6']
# ['씽2게더', '보면서 눈물을 훔치는 노래가 너무 좋았습니다', '10']
# ['태풍', '연기좋고 재밌고 연출좋은데 왜 평점이 이리낮지', '9']
# ['셔터 아일랜드', '초중반부까지는 개 지루하고 노잼이라 음...뭐지? 했는데 극 후반부에는 조금 볼 만했음.빌드업이 너무 길었던 거 제외하면 나..름..ㄱㅊ한 듯?한 번 봤을 때 다 이해하기 힘들 수도 있음.두세 번 봐야 전체적으로 이해 가능할 거 같긴 한데 귀찮아서 안 볼 거임.', '8']
# ['해피 뉴 이어', '정말 영화보다가 안자는 편인 나를 재운 영화', '1']
# ['최후의 Z', '요약 : 역시 니거와 전라도는 믿으면 안 된다', '7']
# ['스파이더맨: 노 웨이 홈', '4DX로 보면서 의자땜에 몸은 난리는데 나도 모르게 아좀 가만있어봐하며 울며  감동하느라 바빴음', '10']
# ['스물', '재밌고 감동이었답니다 우리아들이랑 같이 보면 좋겠단 생각이 들었어요', '10']
# ['스파이더맨: 노 웨이 홈', '잘 만들어 줘서 고마운 영화, 여태 함께해 줘서 고마운 영화들.', '9']
# ['스파이더맨: 노 웨이 홈', '스파이더맨 올드팬을 위한 심심한 잡탕', '6']
# ['타이거마스크', '정원이 2004년도 이후 감 완전잃었으~혹시나역시나..2004년도작품이더 재밌네 관객수마저 최악..ㄷㄷ', '1']
# ['씽2게더', '더빙으로 봤는데 아이들도 넘나좋아하고 특히 조니역의 진영씨가 부른 곡이 넘나 중독있어요~~보고 난 후 더 생각나는 영화에요~~^^', '10']
# ['킹스맨: 퍼스트 에이전트', '액션은 조금 부족할 수 있으나 1차세계대전 발발을 배경으로 한 스토리는 오히려 실존인물 등장으로 상상력이 풍부해진듯~', '8']
# ['경관의 피', '조진웅과 최우식의 케미 좋았습니다재밌었어요!', '10']
# ['씽2게더', '겨울왕국 이후로 시즌2가 가장 잘된 영화. 정말 재밌고 가장 추천하고픈 영화.', '10']
# ['아이스 데몬', '영화가 이미 아이스 데몬', '5']
# ['경관의 피', '영화를 보는 내내 긴장감이 넘칩니다. 배우분들의 연기도 좋았고 간만에 재미있는 영화본거 같아서 기분이 좋네요', '10']
# ['경관의 피', '잼나네요오요오요오요', '10']
# ['스파이더맨: 노 웨이 홈', '진짜 최고..ㅜㅜㅜㅜ', '10']
# ['매트릭스: 리저렉션', '잼너네요오요오요오요', '10']
# ['해피 뉴 이어', '잼나내요오요오요오요', '10']
# ['미나리', '대체 할머니가 한 게 뭐가 있나? 어떻게 되든 곁에 있어주기만 하면 위로와 위안이 되는 것인가? 한국의 외할머니 이미지가 저랬던가? 희생은 어디있다는건지? 내눈에는 그저 민폐 캐릭터로 밖에 안 보였다. 어디서 감동을 느껴야 하나...! 근래 들어 가장 실망하고 허망하다고 생각 든 영화', '1']
# ['라스트 나잇 인 소호', '에드가 라이트 감독 자신의 스타일을 벗어난 장르 작품', '8']
# ['메이드 인 이태리', '아들과 출연했군요 똑닮았어', '8']
# ['전장의 피아니스트', '오랜만에 명작을 보았다', '10']
# ['승리호', '추천 넘 재밌게 봤습니다!!', '10']
# ['스파이더맨: 노 웨이 홈', '기대가 크면 실망도 큰 법. 액션은 좋고 감동도 있었으나 크게 기억남는 감동은 아니었음', '6']
# ['나 홀로 집에', '너무너무 재밌어요 옛날영화지만 지금도 꺼리낌 없는', '10']
# ['스파이더맨: 노 웨이 홈', '재밌었음 시간이 잘가요', '10']
# ['기적', '예고편에서 본 내용이 다일 줄 알았는데 그렇지 않았다. 억지 감동까지는 아닌데 여러 상황 설정에서 개연성이 떨어지는 부분이 많았다. 그래서 크게 흥행하지 못했던 게 아닐까..', '5']
# ['라스트 나잇 인 소호', '환상과 현실 그 중심에서 펼쳐지는 화려한 연극.', '9']
# ['경관의 피', '사운드 믹싱을 잘 못 한건지 대사 전달력이 아쉬웠습니다', '6']
# ['장르만 로맨스', '머냐 진짜ㅋㅋㅋ 좋은 배우들 데리고 만든ㅋㅋ개졸작..', '1']
# ['경관의 피', '조진웅, 최우식, 박희순을 비롯한 배우들의 연기가 좋았고 현실과 허구가 뒤섞인 스토리는 그래서 더 현실적으로 다가오네요. 살짝 루즈한 장면도 있었지만 박진감 넘치는 액션도 좋았습니다. 후속편을 기대해봐도 좋을 듯.', '9']
# ['씽2게더', '스토리도 좋고 주제와 메시지도 좋네요. 템포를 잘 조절한 구성과 전개도 좋아요. 신나고 즐거운 뮤지컬 애니메이션을 지루할 틈 없이 관람한 느낌입니다. OST는 그야말로 최고!!!', '10']
# ['방자전', '조여정의 재탄생! 섹시하고 큐티한 그녀.남자들은 첨으로 방자가 되고 싶었다..', '6']
# ['스파이더맨: 노 웨이 홈', '사실상 주인공이 빌런인 다소 아쉬운 스토리 전개,하지만 스트레인지와 액션신과 삼파이더맨의 조합은 옳습니다', '6']
# ['가위손', '차가운 눈물이 흐릅니다..', '10']
# ['섹시한 미녀는 괴로워', '아이고 의미없다.', '10']
# ['기억의 시간', '비전문가 눈에도출연, 스토리, 캐스팅 배우 궁합이 정말아쉽네요...조연 여배우들 연기가.. 특히', '2']
# ['기적', 'ㅜㅜ 슬펐어요..누나ㅜㅜ', '10']
# ['스파이더맨: 노 웨이 홈', "간간히 액션장면에서는 손에 땀을 쥘만큼 재미있었으나, 그렇게 큰 결정에 있어서 이것저것 바꿔대는 스파이더맨 때문에 조금 어이 없었고, 얘기하는 장면이 너무 길어서 졸기도 했다...평점보고 결정했는데, '그 정도로 재밌진 않은데?'라며.. 의아했으며, 굳이 극장에서 안 봐도 될만했다.", '7']
# ['레미제라블', '개인적으로 뮤지컬 영화는 별로....', '5']
# ['드라이브', '라이언 고슬링이 액션을?  라이언 고슬링은 보통 로맨스나 드라마만 찍는것 같았는데...ㅋㅋ 액션을?? ㅋㅋ 라이언 고슬링은 액션 안어울린다 ㅋㅋ  헌데 영화를보니 드라마쪽으로 가까와 보이는데...액션보다는....ㅋㅋㅋ', '4']
# ['돈 룩 업', '바로 이런 것이 풍자한 말씀이야.', '8']
# ['경관의 피', '최고예요!! 너무 연기를 잘하세요 다들', '10']
# ['고양이에게 밥을 주지 마세요', '지구는 인간 것이 아니에요 공생하며 살아갔으면 합니다.', '10']
# ['마이 뉴욕 다이어리', '자신이 뭐해야할지 아직 모르는 여주인공의 홀로서기 성공기랄까!?', '8']
# ['씽2게더', '신나는 노래와 영상미로 몰아친다!', '7']
# ['노트르담', '싱글맘의 성공과 사링의 좌충우돌기..', '7']
# ['램', '신화적 배경에.. 자연의 섭리에 관한 매력적인 우화..', '8']
# ['슈퍼 빼꼼: 스파이 대작전', '갓 영화네요 잘 봤어요 ^^', '10']
# ['드라이브 마이 카', '중간 중간 졸음이 쏟아지기는 하지만 ,,일상으로 돌아와서도 자꾸 스토리를 되뇌이게 되는 영화 .몇 몇 장면은 강인하게도 와 닿습니다 .쵝오는 아니지만, 한번 쯤 챙겨 보아도 시간이 안 아까운 영화 ^^', '8']
# ['스파이더맨: 노 웨이 홈', '진짜 짱이다...역대급이라는 말밖에... 엔드게임 이후로 가슴이 웅장해지는 영화는 오랜만..', '10']
# ['씽2게더', '씽1보다 더 잼써짐 약간 감동의 눈물도 찔끔 나와서 민망머쓱ㅋㅋㅋ 버스터문 넘귀여움', '10']
# ['숏버스 배우행', '숏버스 시리즈의 마지막편. 진정한 배우되기란 과연...', '9']
# ['스파이더맨: 노 웨이 홈', '역대 마블 영화중 최악 진짜 너무 재미 없어쿠키영상 볼라고 끝까지 기다림', '1']
# ['씽2게더', '씽 처돌이로서 진짜 잼게 봄... 1편 노래들도 진짜 좋았는데 더 좋은 노래가 계속 나와서 소름돋음 ㅠㅠㅠ 진심 극장 의자에서 리듬탈뻔', '10']
# ['고스트버스터즈 라이즈', '추억팔이 이벤트 영화!! 하지만 딱! 그것만으로 2시간을 채우다보니 너무 지루하고 재미없는 영화가 되었다.. 스토리도 엉망이고 연출도 엉망이고 차라리 만들지 말았으면 좋았을 영화', '2']
# ['변산', '마음이 따뜻해지느느 웃음과 감동이 있는 영화예요', '10']
# ['간신', '초호화 캐스팅과 휼륭한 의상, 미술. 그러나 연산군의 처절함을 말하려는건지 진정한 왕을 위한 간신들을 말하려는 건지 그도 아니면 고품격 성인물을 만들고 싶었던건지. 경계선이 모호한 안타까운 작품', '5']
# ['매트릭스: 리저렉션', '다시 만들지 않았으면 차라리 나았을텐데...', '5']
# ['경관의 피', '소설 내용을 좀 알아야할 것 같아요. 후속작 기대', '10']
# ['티탄', '상당히 괴이한 영화...', '6']
# ['해피 뉴 이어', '사랑스러운영화였지만 아쉽', '10']
# ['장군의 아들', '성장 서사의 밀도, 다채로운 액션의 쾌감, 민족적 메시지의 감동.', '8']
# ['아멜리에', '너무나 사랑스런 아멜리에...', '9']
# ['스파이더맨: 노 웨이 홈', '얘들아 사랑해! 고마워...ㅎ', '7']
# ['램', '상당히 괴이한 영화... 엔딩도 그렇고...', '7']
# ['해피 뉴 이어', '내용은 뻔하지만 배우들의 얼굴, 모습을 보면 용서가 된다는...', '8']
# ['스파이더맨: 노 웨이 홈', '그냥 보러갔다가 너무 반가운 얼굴도 많이 보이고 마지막엔 제목이랑 함께 정말 많은 생각을 하게 만들고 슬펐어요ㅠㅠ그래도 너무 재밌었어요!', '10']
# ['드라이브 마이 카', '3시간이 지루하지 않은 영화라는... 특히 유나역의 박유림 배우를 알 수 있어서 좋았네여...', '10']
# ['돈 룩 업', '나는 이 영화를 보고 정치영화라고 생각이 들었다.한쪽으로 편향된 정치는 망한다를 보여주는것 같았다.우리는 좌우를 떠나 항상 정치인들을 의심해야한다.좌우 네편 내편을 떠나 그들이 잘못하면 질타로 두들겨 패야할것 같다.지금 이나라에도 매우 중요한 이야기 인거 같다.', '10']
# ['킹스맨: 퍼스트 에이전트', '스토리는 괜찮은데 콘래드의 중2병스러운 모습은 좀...', '7']
# ['스파이더맨: 노 웨이 홈', '액션신과 내용은 볼만합니다.', '8']
# ['경관의 피', '조진웅, 최우식배우의 연기합이 볼만은 한데 대사소리가 잘 안들리는게 아쉬움...', '8']
# ['천공의 성 라퓨타', '그냥 그랬음. 여기서 뭘 더 느껴야 하나? 무던히도 기계같던 두 주인공.', '6']
# ['씽2게더', '노래도 좋고 아이들과 같이 볼만해여.', '9']
# ['티탄', '전형적인 프랑스 감성의 영화. (프랑스 감성 = 유럽에서도 유명한 사이코적인 비정상적 기괴한 감성 = 프랑스인들은 낭만과 문화의 민족이 아님. 프랑스에서 살다온 미국인들 이야기를 들어보면 가관이다. 낭만의 문화적 자원은 없어진지 오래되었고 지금의 프랑스는 괴상하고 기괴한 문화가 팽배함.)', '1']
# ['해피 뉴 이어', '영화보다가 뛰쳐나간 사람이 이렇게 많은 영화 처음봄..연말분위기는 나나 너무 인물도 많고 스토리가 진부함 ㅠ', '1']
# ['해피 뉴 이어', '인기 배우들이 많이 나오기만 하는 영화도 필요하긴 한 듯.', '6']
# ['돈 룩 업', '배우들은 화려한데 영화가 못 따라가는 느낌', '7']
# ['경관의 피', '일단 한국영화도 기본적으로 자막을 넣어줬으면 좋겠따.', '7']
# ['경관의 피', '연출이 너무 아쉽네요...최우식은 연기를 다시 처음부터 하나하나 다시 배워야 할 것 같아요...연기를 더럽게 못합니다...스토리도 보면서 대충 예상이 되는데 다음씬 내용 적중률 90%..ㅠㅠ', '1']
# ['하이힐', '다들 연기 잘합니다. 집중도 최고!세상에 각자의 본능을 숨기며 살고 있는분들 많겠죠? 다른 내면을 보았습니다. 코미디가 이렇게 슬프진 않겠죠?', '10']
# ['드라이브 마이 카', '잔잔하게 흘러가는 영화인데도 시간 가는 줄 모르고 몰입해서 보게되네요. 22년 첫 영화였는데 매우 만족합니다.', '10']
# ['고질라', '고대콩과 함께 몬버 원탑이다.', '9']
# ['부탁 하나만 들어줘', '최근 본 영화중 최고 전혀예상하지 못한 반전 재미도 최고!!', '10']
# ['경관의 피', '이런 장르를 좋아해서 그런지 너무 재밌게 봤습니다! 소재도 은근 참신한 편!!', '10']
# ['스파이더맨: 노 웨이 홈', '마블 영화를 원래 싫어하던 사람인데 그럭저럭 재밌게 봤음 반전도 신선했고', '7']
# ['스파이더맨: 노 웨이 홈', '진짜완전대박진심완전진짜 최고', '10']
# ['캐롤', '내 인생 영화. 몇 번을 다시 봐도 배우들의 연기에 녹아들고 눈빛과 손짓, 말하는 거 하나하나까지 기억에 남는다. 마지막 장면에서 캐롤과 테레즈의 눈빛은 절대 잊지 못할 것이다.', '10']
# ['고질라 VS. 콩', '개봉 때 봤는데 지금 남긴다.액션은 정말 죽여준다.', '9']
# ['스파이더맨: 노 웨이 홈', '기획과 캐스팅의 승리!돌고돌아 정리정돈을 마치고 원점으로 돌려놓다. 무엇보다 예상했었음에도 불구하고 그가 등장하는 순간은 정말이지 뭉클했다.', '9']
# ['스파이더맨: 노 웨이 홈', '추억 속 배우들이 나와서 반가웠어요', '9']
# ['레이니 데이 인 뉴욕', 'B급 느낌… 대사와 흐름이 허접스러움…', '4']
# ['스파이더맨: 노 웨이 홈', '그냥  ㅜ ㅜ 생각보다 별로ㅜ ㅜ', '8']
# ['스물', '옛날 생각 나게 하는 영화...', '8']
# ['그레타 툰베리', '2021년에 보면서 그레타에 대해 정말 오해가 많이 하고 있었구나 생각을 하게 된 다큐였습니다. 그레타가 찐이였군 이라고 더 확실하게 알게 된 다큐였던것 같습니다!', '10']
# ['부산행', '언제나 다시 봐도 재밌어요', '10']
# ['씽2게더', '생각보다 잼있었다.안보려다 봤는데 잘함ㅎ', '8']
# ['호텔 레이크', 'ㅋㅋㅋㅋ많이들 보삼', '1']
# ['킹스맨: 퍼스트 에이전트', '나쁘지않음', '7']
# ['블랙 위도우', '블랙위도우 왜죽여..', '9']
# ['킹스맨: 퍼스트 에이전트', '와 킹스맨을 이렇게 망쳐놓네. 도대체 이건 만들었을까요', '2']
# ['조조 래빗', '상상 속 친구 히틀러는 패착이였다. 아카데미에서 <기생충>에 질 만해.', '7']
# ['킹스맨: 퍼스트 에이전트', '액션신이 진짜 재밌었고 중년미 넘침', '10']
# ['돈 룩 업', '재치넘치는 풍자를 풀어내는 감독과 명배우들의 조합 최고의 영화', '10']
# ['경관의 피', '너무재밌네요. 보는내내 시간가는줄 모르고 봤습니다.', '10']
# ['스파이더맨: 노 웨이 홈', '그웩을 구하지 못했던 어스파가 mj를 구했던 그 순간의 눈빛을 한동안은 잊지 못할 것같다', '9']
# ['주토피아', '언능 귀여운 주토피아 2를 만들어주세요!!!!', '9']
# ['경관의 피', '너무 많은 관점을 보여주려고 했다. 이야기도 많은데 관점도 다양하니 어지롭고 산만하다.', '7']
# ['해피 뉴 이어', '아쉬운 각본, 연출인데 캐스팅만 호화로움', '5']
# ['경관의 피', '조진웅 연기 너무 잘하네요. 너무 잘봤어요 다른 영화또 보고 싶네요', '10']
# ['경관의 피', '너무 잘봤어요. 영화잘만들었네요. 보고나서 기분이 너무 좋아요', '10']
# ['킹스맨: 퍼스트 에이전트', '유쾌함이 빠지고 진중해진 킹스맨', '7']
# ['버닝', '예술영화  자존감 낯은  유아인  젊은  자화상', '8']
# ['경관의 피', '딱... 킬링타임용...', '6']
# ['스파이더맨: 노 웨이 홈', '존잼존잼 스파이더맨 모든 시리즈를 다 본 사람들을 위한 영화이다', '10']
# ['스파이더맨: 노 웨이 홈', '존잼존잼 스파이더맨 모든 시리즈를 다 본 사람들을 위한 영화이다', '10']
# ['씽2게더', '아빠랑 같이봤는데 진짜 너무너무좋았다.', '10']
# ['퍼스트 어벤져', '절대 67점대 영화가 아니다.', '10']
# ['동네사람들', '저는 재밌게 봤어요  시골풍경도 좋았구요 연기도 다들 좋구', '10']
# ['고스트버스터즈 라이즈', '80년대 생이라면 고스터버스터즈를 봤을거다. 물론 어려서 극장에서 보진못했지만 주말명화나 토요명화... 그리고 추석 설날 특집때 항상했다... 그래서 케빈다음으로 많이 본영화이기도합니다... 주인공들이 많이 늙어서... 참 세월 안타깝네 하면서 봤어요. 스토리가 그렇게 깊이가 있거나 막 재미있는건 아니지만 팬입장에서 추억도 소환되고 좋았어요. 잘봤습니다. 이영화를 잘모른다면 6~7점 정도... 이영화 스토리를 안다면 7~9정정도... 라고 생각하네요... 마지막 장면에서 너무 슬펐어요..', '10']
# ['경관의 피', '역시 믿보배우들이 펼치는 연기대결의 향연..게다가스토리도 지금까지 보지 못한 흥미로운 스토리까지..너무 만족하며 잘 봤습니다ㅎㅎ', '10']
# ['경관의 피', '스폰서 경찰은 능력있고 멋있고 절차 지키는 경찰은 비루하고 고리타분하다는 설정,, 지금이 이명박 시대냐? 10년전에 써진 일본소설 가지고 지금 영화 만들겠다는 놈이나 자금 대준 놈이나 한심하다. 배우들이 아깝다', '6']
# ['이미테이션 게임', '조용한 전쟁영화, 실화바탕의 각색, 담백한 연출. 자연스럽게 동시대에 개봉한 아메리칸 스나이퍼랑 비교된다. 둘다 너무 훌륭했고, 또한 너무 훌륭한 작품들이 많은 한 해였다. 인터스텔라, 버드맨, 위플래쉬, 사랑에 대한 모든 것…', '8']
# ['스파이더맨: 노 웨이 홈', '다보고나니 얼굴이 눈물로 축축해져 있었다.', '10']
# ['경관의 피', '몰입도 있고 긴장감 있고 연기 좋지만 뭔가 남는 기억이 없는 느낌. 뭐가 부족한거지?', '8']
# ['꿈의 제인', '영화가 너무 무거운 이야기를 담고 있다고 느끼면서도 내가 싫어할 정도의 극단의 현실적인 무거움은 아니었다. 현실과 영화를 적당히 버무려 놔서 보기에 거북하지 않은느낌? 지수가 묻힌 곳에서 대포에 의해 소현이 죽었다면, 그곳을 벗어나 갈대숲이 있던 그 강에서 자살했다면, 1부에서 손목을 그어 자살하려 했던 것처럼 모텔 욕조에서 자살했다면 상업영화의 프레임에서 벗어나지 못한 그냥 영화였을 것이다. 끝내 소현은 죽지 않았고 나는 그것에  묘한 기시감이 들었다. 사람은, 인간은 영화에서 처럼 쉽게 죽지않는다는 것이 지독한 현실이다. 이런저런 죽고싶은 일들을 수없이 겪고도 그런 고통의 기간을 지나오더라도 사람은 쉽게 죽지 않더라.  여러 생각이 드는 영화… 아직도 영화에서 헤어나오지 못하겠다.', '10']
# ['씽2게더', '저는겁나 재밌었어요 tv에 나오면 무조건보세요', '10']
# ['레이니 데이 인 뉴욕', '상위 1%의  부자들도  행복을 찾아가는 과정은  결국 일반인  사람들이 사는 것과  비슷하네요,그런데 머리좋고 피아노 멋지게 연주하는 것은  부럽다', '8']
# ['고스트버스터즈 라이즈', '재밌었어요. 1편으로 끝날게 아니네요. 고스트버스터즈 시리즈가 계속 이어지면 좋겠습니다. 여러 예전영화들이 시리즈를 이으려고 후속작들이 나왔는데 그래도 제일 스토리나 개연성이나 어색하지않게 만들어진것 같아서 재밌게 봤습니다.', '10']
# ['해바라기', '진짜다신없을명작이지.OOO시르면 나가OO이형', '10']
# ['경관의 피', '최우식의 다른 면을 보여주는 영화네요 조진웅 연기도 좋았어요', '8']
# ['바람아 안개를 걷어가다오', '단편영화는 스토리가 중요한데.. 너무 허접함', '2']
# ['옥자', '부드러운 전개가 인상적이었음', '10']
# ['타이타닉', '이걸 볼 수 있는 내 인생 레전드. 진짜 개 쌉 레.전.드', '10']
# ['씽2게더', '영상과 음악에만 몰빵함', '6']
# ['둠스데이 - 지구 최후의 날', '볼만함.네이버 평점 이상함', '10']
# ['돈 룩 업', '참신해서 좋다. 곧 망할 지구를 영웅들이 구하는 것이 아니라 각자의 방식으로 망할 때까지 버틴다.', '9']
# ['연애 빠진 로맨스', '캐릭터 이름부터 재밌었고, 꾸준히 재밌었어요', '8']
# ['해피 뉴 이어', '러브 액츄얼리 리메이크 버전인가요? 너무 비슷해서 신선함은 없었으나 배우들이 눈은 즐겁게 해주네요. 캐스팅 점수는 높게 드리고 싶습니다. 젊은 배우들보다 이혜영씨가 제일 연기도 잘하시고 예쁘신 것 같아요.', '5']
# ['킹스맨: 퍼스트 에이전트', '감동포인트 교훈도 있고킹스맨 팬들이라면 꼭 보시길 추천드려요..개인적으로 3편이 가장 ㅈㅐ미있었어요 저는아닌가 어쨌든 킹스맨 인생 영화입니다>>', '10']
# ['씽2게더', '1편보다 이야기적인 부분에서 그리고 화면적인 부분에서 더 좋았음', '10']
# ['불한당: 나쁜 놈들의 세상', '이건 미친 영화야 뒤늦게 설경구한테 빠지게 만든 영화', '10']
# ['타이거마스크', '탄탄한 스토리 뛰어난 연기력 최고의 명작이다', '10']
# ['매트릭스: 리저렉션', '나오지말았어야할..', '2']
# ['세자매', '인생은 멀리서 보면 희극 가까이서 보면 비극이라던데 가까이서 보니 정말 초초초비극이었다', '10']
# ['레이디스 나잇', '캐릭터들이 진부하다~ 뚱뚱한데 멍청하고 일만 저지르는 꼴보기 싫은 친구에 똑똑하고 부잔데 상처투성이~ 일도 안하면서 반사화적인 광신도~ 파티광~그리고 젤 정상적인 주인공까지 ㅋㅋㅋ 재미없음;; 넘 나대는 캐릭터가 있음 보기싫어짐;;그래도 요한슨 보는 재미는 있음', '6']
# ['메모리: 조작살인', '탄탄한 스토리 뛰어난 연기력 대한민국 역사에 남을 작품이다', '10']
# ['돈 룩 업', '띵작이다 트럼프, 일론 머스크같은 사업가, 대중 등 사회 전반적인 부분에 있어서 비판하고 있다. 영화에서는 긴박함을 위해 혜성을 예로 들었지만 지구 온난화로 인한 기온 상승을 가져다 써도 무방할 정도로 현실적이라고 보았다. 투표의 중요성 또한 강조하는 것이 아닌가 싶은 영화였다. 물론 대통령 되려고 하는 사람들이 그 나물에 그 밥 같은 느낌도 있지만 말이다. 영화가 다 끝나고 나서는 만약 지구 멸망이 내일이라면 무엇이 하고 싶을지에 대해서도 떠오르게 한다. 그러면서 내 인생에 있어서의 본질적인 삶의 의미에는 무엇이 있을지 고민하게 한다.', '10']
# ['경관의 피', '너무 재밌어요! 같이 간 친구들도 재밌다고 명작이라고ㅋㅎㅎ 했습니다. 대사, 발음 안 들린다고 하시는 분들이 있던데 초반에만 그렇고 뒤로 좀만 가면 괜찮습니다. 영상미도 좋고, 조진웅 최우식 박희순 권율 박명훈 배우님들 연기도 좋고, 몰입감이 너무 좋았어요.', '10']
# ['매트릭스: 리저렉션', '세계관이 신박하지 못함액션 영화인데 주인공이 너무 늙어 버림차라리 다중우주론을 세계관으로 하고 주인고을 젊은 애들로 했다면', '4']
# ['뱅드림! 필름 라이브 세컨드 스테이지', '100번 봐도 질리지 않을거같음', '10']
# ['어떤살인', '여자들의 피해망상을 불러일으키는 영화다 . 실제로 이런사례는 1/1000확률이다. 그런데 너무 각색을해서 여자들이 이영화를보고 모든남자를 잠재적 강간범으로 생각할거같다. 이영화는 여자들에게 페미사상을 일으키는 잠재적 페미영화라 규정할수있다. 솔직히 영화를 영화로봐야지, , 이세상에 모든 남자를 강간범취급하면서 시위하는 정신나간 행위는 안했으면한다', '1']
# ['온다', '이것은 굉장히 신선하다', '10']
# ...
# ['콰이어트 플레이스', '너무 뻔한 전개였고 다음 내용 예측이 너무 쉬웠음... 반전도 없고 전 별로임', '4']
# ['화이트: 저주의 멜로디', '엄청 옛날에 봤지만 나름 기억에 남고 ㅜ,ㅜ아직도생각나는 영화 노래랑 춤이 잊혀지지가 않음', '10']
# ['러브 액츄얼리', '크리스마스보다 조금 더 늦게 봤지만, 오늘이 크리스마스 같네요 :)', '9']
# ['헝거게임:모킹제이', '그냥 파이널을 위한 준비영화. 이걸 보고 일년뒤에 파이널이 나온다는 소식을 들었다면 욕했겠지만 몰아서 보니까 나름 괜찮았다. 잔잔하고 좀 지루하긴한데 그렇기 때문에 파이널이 더 몰아칠 수 있는 게 아닐까. 파트1,2 한번에 네시간짜리 영화로 봐야함. 근데 어이없는 건 왜 따로 소제목을 달았는지….. 사람들 헷갈리게', '7']
# ['어메이징 스파이더맨 2', '피 하나 안 줬다고 친구 여친 조져놓고 그걸로도 분이 안 풀려서 악당 조직까지 모으겠다는 해리 오스본을 난 참 이해를 못하겠네.', '4']
# ['경관의 피', '뭔 말을 하는지 모르겠음 스토리 자체도 엉성해서 보면서도 이해하려고 노력했는데 대사가 안 들려서 이해가 안 됌 ㅜ 특히 영화 초반에 심함 그리고 결말이 정말..엥 이렇게 끝나?이런 느낌 Bgm이 조금 안 어울렸음', '6']
# ['스파이더맨: 노 웨이 홈', '데어데블 나만 본거 아니지?', '9']
# ['더 캡틴', '와 연기력 쩐다 실화라니', '10']
# ['명당', '지성 연기 너무심하네요;;; 걍 그래도 재미있게는 봣으니 이정도 점수주고 갑니다;;', '7']
# ['고스트버스터즈 라이즈', '다시 누워라... 아직 일어날준비가 덜된듯..', '4']
# ['헝거게임: 캣칭 파이어', '1편도 재밌었는데 2편은 보고나서 소름돋음(개인적 의견) 헝거게임 시리즈 통틀어 최고의 명장면은 캣니스가 천장으로 화살을 쏴서 게임 틀을 깨는 장면이라고 생각함. 근데 한가지 궁금한 점은 초반에 캣니스는 왜 피타한테 철벽쳤던 건지… 말도 잘 안하고 같이 있기도 꺼리고. 시즌1 죽을 고비를 넘겨서 살았으면 우정이 더 깊어지지 않나??', '10']
# ['고스트버스터즈 라이즈', '옛날 고버 배우들 보니 좋았네요.ㅜㅜ', '10']
# ['천년호', '동양적 판타지 느낌의 영화 중국풍 판타지에+ 한국식 드라마요소가 섞인느낌 좀더 잘 살렸으면 수작이였을텐데 아쉬움이 살짝 남는다', '7']
# ['에이리언 2', '몇OO이 지낫지만 지금봐도 손에 땀을쥔다', '10']
# ['경관의 피', '초중반은 궁금하고 그럴싸하게 시작은 했지만 뒤로 갈수록 스토리가 이상해지더니 이해할 수가 없었다.  반전도 무미건조 했고.. 그냥 연기 잘하고 좋아하는 배우들 나와서 봤는데 약간 실망했고 배우들 연기만 남은 영화였다. 원작은 안 봤지만 한 번 보고 싶게 만들었다. 조진웅은 말할 것도 없이 연기 잘했고 권율의 악역 연기도 잘했는데 최우식이 무게감 있는 연기랑 안 맞는 느낌이었다. 그래서 초반에 죽은 경찰은 누가 죽인 거지 진짜 조진웅이 죽인 건가.. 나중에 넷플로 나오면 자막 키고 다시 보고 싶다.', '7']
# ['엘레강스 에스코트', '스토리...연기...모두 상하나 받을만한데~', '10']
# ['순수의 시대', '드라마 태조이방원 보다훨씬 더  재미있음 배우들 연기도 드라마 태조이방원 보다100배는 더 잘함KBS 태조 이방원 배우들 연기 더럽게 못해서몰입이 않됨특히, 박진희.예지원 .주상욱.이광기진짜 연기를 너무 못해', '10']
# ['가문의 위기 - 가문의 영광 2', '시즌1과는 세계관이 공유가 안되지만 장르와 컨셉을 비슷하게 가져감 후속과 계속연결되서 본격 가문시리즈1편이라 봐도될듯 시즌1이 좀더 드라마적인 요소가 컸다면 시즌2는 직관적인 코믹요소가 더 커짐', '7']
# ['유체이탈자', '토탈리콜+메멘토 를 섞어 놓은듯한 내용. 악역 캐릭터가 좀 억지스러운거 빼곤 지루한 부분없이 재밌게 볼수 있었습니다.', '8']
# ['두 개의 달', '전혀 예상치 못한 반전..소름?-', '10']
# ['신용문객잔', '임청하 눈물흘리며 술마시는 장면은 Good~', '10']
# ['아멜리에', '사랑스럽다 ㅎㅎ', '9']
# ['오아시스', '메마른 시선들 사이에서 피어난 그들의 오아시스', '10']
# ['콘돌은 날아간다', '1점도 주기 아깝다 조재현이라서 불필요한섹스씬 노출 채모는 왜?', '2']
# ['터널', '재미없고 지루함ㅡㅡㅡㅡ', '2']
# ['스파이더맨: 노 웨이 홈', '절대속지마세요 스파이더맨 최악의시리즈팬심때문에 뛰처나가고싶은거 억지로 꾹꾹참고보다가 스트레스에 두통와서 하루날리고 고생함.', '1']
# ['매드맥스: 분노의 도로', '미쳤다, 같이 미칠 수 있어서 좋았다..이걸 왜 지금에서야 봤는지 후회될 뿐..', '10']
# ['사냥의 시간', '미치겟음??-이럴수가', '1']
# ['헝거게임 : 판엠의 불꽃', '일단 세계관 대박. 10년 전인데도 CG 대박. 영상미, 음악, 배우들 연기 때문에 흡입력이 장난 아니라 시간 가는 줄 모르고 봤음. 그런데 피타와의 로맨스 부분은 불친절함. 응?;; 여기서 갑자기?;;;; 싶은 부분이 많았고 왜 여주가 피타를 사랑하는 척 해야하는지 이유 좀 알려주고 고민하는 과정을 보여주지 관객 모르게 지들끼리 갑자기 연애모드로 들어감ㅜㅜ', '8']
# ['싱크홀', '와 진짜 심각하다.. 7점도 아까운데', '1']
# ['스파이더맨: 노 웨이 홈', '때론 답답하게 때론 즐겁게, 톰스파의 뭉클한 성장 이야기', '7']
# ['인싸', '어려웠을텐데 열심히 한 것 같아서 재미있게봤습니다. 동현 배우님 SNS에 떠서 동현배우님인가 했는 데 역시!! 너무 보고 싶었어요 !', '10']
# ['파워 오브 도그', '미묘한 감정들이 좋을뻔했지만 이해가 안가는 구석들이 있고 여운에 남는것도 아니고 음악이 집중력을 높였고 미스테리하고 뭔가 일어 날것 같은느낌을 줬음', '6']
# ['씽2게더', '아이와 함께 봤는데 웃으면서 너무 재밌게 봤어요', '10']
# ['변산', '진짜 너무 재밌게 봤는데 ㅋㅋ', '10']
# ['돈 룩 업', '미국의 쇼비즈와 정치를 지구 멸망과 잘 버무린 블랙 코미디였다. 요즘 본 영화 중에 최고였다. 브론테록 ㅋㅋㅋㅋ', '10']
# ['기적', '오랫만에 따뜻한 영화였습니다. 감사합니다.~~^^', '10']
# ['돈 룩 업', '기후변화에 빗댄, 정치에 희생된 본질을 풀어낸 명작.', '10']
# ['경관의 피', '난 극장 문제인줄 알았는데 영화 자체에 문제가 있었구나. 조진웅 연기는 진짜 일품. 고뇌가 가득해 보이는 그 특유의 표정. 개인적으로 최우식 너무 안 어울렸음. 정해인이나 이재훈, 박정민 중에 한명은 어땠을까.', '6']
# ['낙원의 밤', '강추요. 연기들 다 훌륭.', '10']
# ['모가디슈', 'ㅇ로나만 아니였으면 더 흥행했을텐데 아쉽네요ㅠㅜ 간만에 집중해서 본 국내영화였습니다', '10']
# ['경관의 피', '배우들 연기는 좋지만 스토리는 매우 불친절한 영화..', '3']
# ['타짜: 원 아이드 잭', '솔직히 말하면 1에 비해 재미없는건 사실이긴해도 현대판에 맞게 기승전결 잘 짯다고 생각함 2<3<1 인듯 그냥 재밌음 킬링으로 좋은듯', '10']
# ['기적', '이성민씨의 연기는 대한민국 최고인거 같아요. 맡은 배역에 완벽하게 녹아드는…사투리도 너무 자연스럽게 잘 하네요맘이 몽글몽글 따뜻해지는 작품이네요', '10']
# ['경관의 피', '조진웅의 연기는 두 말 할 나위 없고, 대사들도 하나하나 무겁게 느껴졌어요. 최우식의 이런 역할도 역시 잘하네요. 최고! 다만, 박희순 배우님 대사만 묻혀버리는데 박희순 배우 연기할때만 음향이 왜 이모양인건지;; 분명히 편집 과정 꼼꼼히 거쳤을거고, 시사회도 했을거고, 다 확인할만큼 했을텐데 이런 음향 문제는 처음 봅니다;;', '7']
# ['웬디', '재밌다재밌다재밌다재', '5']
# ['돈 룩 업', '재밌다 .. 무슨 다큐같은건 줄 알았는데 사회 지적+ 영상미 연출을 잘 하심 . 브금들 덕분에 지루하지 않고 재밌음 진짜 ㅜ 기대 이상', '10']
# ['엔칸토: 마법의 세계', '이 영화를 으른이 보는 관점으로 재밌다 재미없다로 보지 말고아이들 시선으로 따듯한 가족애를 화려한 색채와 신나는 음악으로 보기 좋게 꾸며낸 영화로 보면 충분한 영화였다.', '10']
# ['6년째 연애중', '8년째 연애중이라 이 영화를 보고 싶었어요.연애도 연인마다 다양한 모양을 가지고 있어서 그런지 저에게는 공감이 잘 가지 않는 영화였습니다. 재미로 불만해요:)', '6']
# ['씽2게더', '경관의 피보단 3배는 재밌음모든 연령대가 유치하지않게 베스트송 듣으며 재밌게 볼수있는 웰메이드 무비', '10']
# ['북샵', '강한자가 약한자를 언제든 짓밟고 뺏을수있다는 교훈적인영화.에밀리 모티머때문에 보긴했지만 불편한영화.', '8']
# ['매트릭스: 리저렉션', '와우짱재미...있어요', '10']
# ['리플리', '이 연기력을 표현할 마땅한 단어가 없다.', '10']
# ['사막을 건너 호수를 지나', '재밌다재밌다재밌다재', '5']
# ['고스트버스터즈 라이즈', '내가 고자~~~~ 라니~', '6']
# ['매트릭스: 리저렉션', '평점이 생각보다 낮넹. . . .나는 오랫만에 다시본 메트릭스 너무재밌게봄', '10']
# ['경관의 피', '시작부터 너무 지루함. 스토리는 나쁘지 않은데 전개가 너무 느리고 답답함. 배우들 연기가 아까움.', '6']
# ['파이란', '집중도 최고.너무감동 ㅜㅜ♡', '10']
# ['돈 룩 업', '이 시대를 관통하는 영화... 무딘 위기의식 극 중 말하지 과학자들 말 좀 쳐들으라고~', '10']
# ['아무도 없는 곳', "말로 다 표현 할 수 없는 이야기에요.예고편까지도 뮤직비디오와 소설책의 형식으로 도 있고 정말 오묘하고 직관적으로 깊은 울림을 주는 느낌이 오게끔만들어져서 보석같은 영화라는 느낌을 받았어요.저는 이야기가 전혀 난해하지 않았어요.제 개인적인 상황, 친구가 스스로 아픈 선택을 하고 얼마 안 되어서 혼란스러운 상황에할아버지가 갑자기 아파지시면서 병상에 계시고 그러는 동안 아픔이 가시지 않은 채로 마음이 너무 힘든 상황이었는데 진하게 위로받는 영화였어요.저도 이야기를 만들고 영상을 만드는 사람이라서 소설을 만드는 작가가 주인공으로 등장하면서 묘하게 이입이 되었습니다.나만 겪는 것은 아니지만 모두가 겪을 수 있고 나만의 어두움 처럼 보이면서도 사실을 알고보면, 주변을 돌아보면, 누구나 겪을 수 있는 '주변사람, 가까웠던 동물과의 사별'이라는 깊고 공허한 아픈 이야기들이 한 편의  문학으로 승화되는 것이 신비롭고 오묘하게 표현되어서 잊을 수 없는 이야기였어요.꿈같은 느낌을 주면서도 현실과 이어집니다.따뜻한 위로를 주셔서 깊이 감사드립니다.", '10']
# ['너는 내 운명', '역시 전도연이다. 그 자체로 하나의 이야기가 되는 대배우', '10']
# ['경관의 피', '재미도 있었고 지루하지 않아 좋았습니다. 박강윤같은 최민재같은 경찰들이 있다면 희망적이겠지요.', '10']
# ['클레멘타인', '솔직해지자 이젠;; 제발!', '1']
# ['발레리안: 천 개 행성의 도시', '심혈을 기울였다기엔 샛길이 너무많다.', '7']
# ['상견니', '여운 가득 빠져서 봤습니다', '10']
# ['타오르는 여인의 초상', '절제됨에서 오는 감동이 더 좋다.', '10']
# ['카모메 식당', '삶이란 적당한 온도의 무언가와 꾸준히 함께 가는 것', '10']
# ['해피 뉴 이어', '개나소나..연기하는거냐?ㅎ  B급들의 향연..ㅋㅋ', '2']
# ['웬디', '늙음을 인정하란건지, 동심을 유지하란건지 감독의 연출실패 영화는 너무 지루하고 판타지도 아닌 어중간한 현실화에 무엇을 말하고 싶었는지 난해함. 세상에 나오지말았어야할 영화다', '2']
# ['명탐정 코난: 비색의 탄환', '강력 추천!! 메구레 반장 역시 마지막에 해결사!', '10']
# ['인페르노', '잼있음 이 시리즈는 기본 이상은 항상 해줌', '8']
# ['돈 룩 업', '편집이 어지러울 수 있지만 대체적으로 재밌고 깊은 감동을 주네요', '8']
# ['죽은 시인의 사회', '"오 마이 캡틴이여" 적어도 제자 마음속엔 살아있으리', '8']
# ['돌멩이', '울면서 밧네요  이일화가 정말 실화라면....지적장애를 가지신분들이 고통 받지 않앗으면 좋은세상이 왓으면 합니다', '10']
# ['씽2게더', '애니메이션에서 보는 즐거움과 듣는 즐거움을 동시에 느낄 수 있음. 나도 모르게 발로 박자맞추면서 같이 즐기게 됨.', '10']
# ['해탄적일천', '에드워드 양의 영화를 극장에서 볼 수 있는 것 만으로도 너무 좋았다', '10']
# ['어메이징 스파이더맨 2', '스파이더맨 중 가장 인상 깊은 영화이다', '10']
# ['경관의 피', '스토리도 탄탄 배우들도 연기를 잘하네요~오래간만에 재미있게 영화 보았습니다~', '10']
# ['노웨어 스페셜', '마이클에게 필요한 건 두 명의 부모가 아닌, 진정한 사랑으로 돌봐줄 보호자. 마이클이 좋아하던 빨간색 문에서 희망을 보았다.', '9']
# ['전장의 피아니스트', '전개는 익숙하지만, 시리아 내전의 참상은 잘 담아냈다. 베토벤의 발트슈타인이 울려퍼지는 엔딩도 인상적', '8']
# ['극장판 귀멸의 칼날: 무한열차편', '이런 미친 애니는 없었다 몇번을 봐도 안 질릴 내 최애 애니아악 내 렌고쿠 ㅠ', '10']
# ['경관의 피', '배우들 연기도 좋고, 마지막까지 긴장감있게 봤어요', '8']
# ['닥터 두리틀', '내가 진짜 어벤져스  멤버들중에서 아이언맨이 최애 캐릭터라서...로다주와의  의리로 극장가서 봤었다별점도 의리로써 주는데 의리빼고는 1점입니다ㅠㅠ', '10']
# ['사이에서', '내인생 최악의 사투리연기...진짜 참고 보려고 노력했지만도저히 볼수없는 연기....차라리 그냥 서울말을 쓰게하지...연기자는 그렇다고 쳐도 감독이며 스텝들은 눈과 귀가 없나 싶을정도로 저급영화....', '2']
# ['드라이브 마이 카', '볼게 없어서 봤는데3시간 뚝딱이었다', '10']
# ['최종병기 활', '초반에 딸년 ㅈㄴ 꺅꺅대고 트롤짓하길래 발암걸려서 끌뻔했네', '7']
# ['우아한 거짓말', '사이좋게 지내라 얘들아ㅠㅠ', '7']
# ['트레이닝 데이', '이 영화 평점 낮게 준 인간들, 개인취향이긴한데  트레이닝데이 이후로 경찰비리 영화는 거의 이 영화의 아류작이 많음. 특히 대한민국 범죄영화. 덴젤 워싱턴이 괜히 아카데미 남우주연상 받은 줄 아나..무려 20년전 영화다, 20년전.', '10']
# ['씽2게더', '전혀 지루함 없이 지나간 두시간ㅠ 스토리 구성 좋고 감동까지 주는 영화..♡ 애니메이션이지만 어른들이 보기에도 좋아요 !! 그리고 이번 곡들이 다 넘 좋음.. 콜드플레이 션멘데스 곡 등 내적댄쓰 유발ㅎ 뒤에 공연부분은 넘나 또 보고싶음', '10']
# ['사라진 시간', '조금 어려운(?) 내용이지만 볼만했다.', '6']
# ['코다', '딸에 목에서 울려 퍼지는 소리가 아니라 진동을 느끼는 아빠', '8']
# ['미쓰 와이프', '엄정화 언니만의 연기 진수를 맛 볼 수 있어요~~별 기대없이 봤다가 감동 감동입니다', '10']
# ['브이아이피', '아무리 영화라지만 초반장면은… 정말 너무 잔인하고 기분이 더럽습니다… 보신분들은 아실겁니다..', '2']
# ['퍼펙트맨', '존잼 꿀잼^^조진웅 설경구 진선규 최고~!!', '10']
# ['경관의 피', '그래도 만들면 중간은 가는 에이스메이커,늘 중간까지만 가서 멈춰버린다는게 문제긴 한데....', '6']
# ['비스트', '와 . . . 이런 명작이 !!   시나리오가 상당히 탄탄해요 !! 끝까지 재미있게봄 ~', '9']
# ['엽문4: 더 파이널', '중뽕 영화이긴 한데, 어차피 1편부터 그랬었고 그거 모르고 본 사람은 없잖아? 견자단이랑 스콧 앳킨스가 붙는다니까 보는 거지 뭐 ㅎㅎ. 영화의 본연의 목적인 액션에는 만족했음.', '7']
# ['그날, 바다', '드라마 볼시간에 이거 꼭한번 봅시다 밝혀지지가 않은게 아니고 밝히지않는거군요 가만히 보고만 있는 내가 부끄럽습니다..', '10']
# ['경관의 피', '댓글에 대사전달이 잘 안됐다고  하는데 저는 그런거 못느끼고 잘봤습니다 배우님들(조연배우님들도) 연기좋았고 최우식배우 이런 역 첨인거 같은데 잘어울리고 연기도 역에 맞게 좋았어요 잘봤습니다^^', '10']
# ['스파이더맨: 노 웨이 홈', '보면서 눈물 흘렸어요. 3번... 정말 인생영화입니다.', '10']
# ['기적', '2000~2010년 영화들 이래 정말 처음으로 영화다운 영화를 봤습니다. 감동,스토리,연기 뭐하나 빠지지않는 정말 명품영화였습니다. 덕분에 살면서 처음으로 감상평이란걸 남기고 갑니다.감사합니다.', '10']
# ['경관의 피', '보통 영화를 보면 , 전개 위기 절정 결말 순인데. 이 영화는 구분이 잘 되질 않았다. 계속 위기 - 절정의 반복이랄까 .. 그래서인지 러닝타임이 너무 길게 느껴졌고 마지막에는 지루하게 느껴질 정도였다,,시도때도 없이 나오는 어울리지 않는 배경 음악 또한 너무 별로였다. 배우들 연기는 좋았다', '7']
# ['돈 룩 업', '그냥 찐! 현실을 반영한 미국코미디. 너무 반영해서 웃어야는지 울어야는지는', '10']
# ['백만장자의 첫사랑', '가람아 안녕? 너랑 처음이자 마지막로 같이 봤던 영화야.. 이 영화 볼때마다 니 생각 많이 나더라..어디서 잘살고있는진 모르지만 어디선가라도 행복하게잘 살고있길 빌게', '9']
# ['유체이탈자', '내용이 이해가 잘안감.. 평점이 이상한듯', '2']
# ['스파이더맨: 노 웨이 홈', '첫 관람의 감동을 잊을 수 없는 영화였다.', '10']
# ['스파이더맨: 노 웨이 홈', '말 안 듣는 스파이디가 짜증나지만 그 모든 것을 위한 것이었던 빌드업', '8']
# ['조디악', '이게 영화다 ㅎㅎㅎㅎ 최고', '10']
# ['샌 안드레아스', '너무 재밌긴한데, 지진이라는데 거의 지구멸망수준이라 현실감은 조금 떨어짐..', '10']
# ['컨테이젼', '코로나가 올거라는걸 알고 예언 한것같아요..', '10']
# ['해피 뉴 이어', '진부한 스토리에 하품이 나네요', '4']
# ['러브레터', '몇 번을 봐도 좋고 아련하다..하지만 아키바 역은 몇 번을 봐도 이해가 안 되고 왜이렇게 이기적인 지 모르겠음', '10']
# ['사랑을 놓치다', '굳이 이혼소송별거중에 같은 소속사이적하고 굳이 같이 찍은 정황증거나 다름없는 영화. 김c의 고백뮤비랑 같은 장르의 작품.', '2']
# ['해피 뉴 이어', '늙으막하게 감동 받았읍니다.스토리는 그랬지만 잔잔하고 따뜻했네요.삶을 반성하면서 재미있게 잘 봤읍니다.', '10']
# ['이터널스', '이터널스는 진짜 어벤져스보다 명작이다', '10']
# ['경관의 피', '호불호 많이 갈리더라고요..기대 없이 봐서 그런지~ 생각 보다 잼있었어요~', '8']
# ['홈', '절제된 연기와 스토리가 너무 좋은 영화입니다준호 내면연기에  몰입감이 높았어요너무 마음이 아프네요', '10']
# ['해수의 아이', '굉장히 감독의 세계속의 이야기에만 빠져있는 영화. 영상미와 노래는 좋으나 주제는 한없이 심오하여 이해하기가 힘든 영화. 다 보고 나서 "....?"하게 되는', '1']
# ['모가디슈', '김윤석최고 류승완최고', '10']
# ['연애 빠진 로맨스', '영화관 가서 또 보고싶다..', '10']
# ['돈 룩 업', '시니컬하고 결말도 그렇게 끝나서 좋았음', '9']
# ['보통사람', '가슴 찡한 명화 과연 지금은 저런 인간 아닌 인간들이 없을까?', '10']
# ['스파이더맨: 노 웨이 홈', '폭력을 없애는 비폭력의 힘. 이 영화가 그 움직임에 보탬이 되길', '7']
# ['내 사랑', '넷플릭스에서 우연히 방에 불끄고 보게됬는데 행복이란 사랑받는 것 위하는 마음 따뜻한 관심 작고 소중한 것 이라는 생각이 드네요 자신의 행복이 창문안에 이미 다 있다고 하는 대사에서 지치고 정신없는 지금의 경쟁사회에서 잠시나마 행복은 가까이에 있을수 있다는 깨달음을 주는 작품이였습니다', '10']
# ['스파이더맨: 노 웨이 홈', '딱 기대한만큼만', '8']
# ['엑시트', '등장인물들 소리 빽빽 지르는거 너무 듣기 힘들었다 특히 임윤아는 왜 보면서 그렇게 빡치는지 잘 모르겠네 빌어먹을 신파 안넣으면 한국영화가 아닌가', '2']
# ['분노', '믿음 동정 분노 의심 사랑 후회', '8']
# ['스파이더맨: 노 웨이 홈', '재밌게 봄 스파이더맨 시리즈 악당들이 집합한다는 스포는 안 밟아서 더 재밌었음', '10']
# ['장르만 로맨스', '재밌는데 평점이 왜 이리 낮나?', '9']
# ['씽2게더', '재밌다 1편보다재밌고 아는노래많아서신남 ㅎ', '10']
# ['경관의 피', '스토리가 좀 이해가 잘 안되고 결말이 너무 K-엔딩임', '8']
# ['해피 뉴 이어', '마음에 오래 남을 영화ㅠㅠ순수하고 부담없이 착한 영화 좋다 이렇게 고요하게 물흐르듯 연애하고  결혼하고싶다. 그냥 따뜻했음', '10']
# ['매트릭스: 리저렉션', '마지막에 그가 트리니티가 된 것도 편견을 깨서 인상깊었고, 트리니티가 애널리스트에게 아이들을 이용한 벌이라고 때린게 찡했습니다. 감정을 이용해서 사람을 통제하는 우리 세상에 순응하지말고 다같이 사랑하고 화합하는 세상이 왔으면 좋겠습니다. 감독이 매트릭스 전편을 통해서 말하고자하는게 이거인거같습니다.', '10']
# ['스파이더맨: 노 웨이 홈', '지금까지 스파이더맨 시리즈는 노 웨이 홈을 위한 준비', '9']
# ['트와일라잇', '하 스토리는 진부하고 볼거리는 없고 신파에 클리셰에 멜로씬은 오글거리고 진심 이게 재밌냐... 1편 보고 바로 접는다. 이따위 수준들이니 늑대소년같은 쓰레기 것도 흥행 떨었지. 뱀파이어 보고 싶음 반헬싱이나 봐라 차라리들.', '6']
# ['매트릭스: 리저렉션', '첫경험의 강렬함은 다시 오지 않는군요.', '5']
# ['1987', '실제 있던 일 이라는게 믿기지않는다', '10']
# ['썬더 포스', '전 생각보다 되게 재밌게 봤어욤', '10']
# ['먼 훗날 우리', '로코인줄 알고 봤다가 눈물 펑펑', '10']
# ['기적', '스토리도 좋았고 배우들 연기도 좋아서 너무 잘봤어요 엉엉 운건 비밀~@', '10']
# ['싱크홀', '재밌음니다재밓습니다', '10']
# ['해피 뉴 이어', '코로나 시국에 우울한 마음을 힐링 해주는 영화  해피뉴이어 너무 재미있게 봤네요.', '10']
# ['스파이더맨: 노 웨이 홈', '어메이징 파커가 mj 구하고 눈물 맺힌 장면에서 구하지 못한 장면이 스치며, 5초만 시간을 더 주었으면 같이 울었다', '10']
# ['스파이더맨: 노 웨이 홈', '마블영화에 스파이더 맨 시리즈에 더 바랄 것이 없었다.', '10']
# ['콰이어트 플레이스', '공포물류는 좋아하지 않지만 소재가 참신하다 영화에서 소리가 차지하는 비중이 적어도 30% 이상일텐데 배경음과 소리를 최소화하고 이정도 긴장감과 몰입감으로 끌고가는게 대단하다 평점 7.8', '8']
# ['고스트버스터즈 라이즈', '이번 고스트 버스터즈 새 시리즈를 보면서 느낀점은 묘하게 고전 시리즈 1편과 2편의 느낌들과 특정 장면들이 떠오르는 씬들이 많이 보여서 의도했나 싶었는데 예전 시리즈들을 다시 찾아보니 확실 해졌네요. 원작 시리즈를 즐겨봤던 팬들에게는 상당한 추억보정도 크게 작용한다고 생각합니다. 신구의 조합도 좋았구요. 마지막 클라이막스는 살짝 감동이었습니다.', '8']
# ['스파이더맨: 노 웨이 홈', 'N차 관람 가능 영화 ㅠㅠ', '10']
# ['고장난 론', '진짜 너무 재밌었음 기대별로 안하고 가볍게 보려했는데 기대 훨씬 이상이였고 너무 재밌음 꼭 봐보세요 다들 진짜', '10']
# ['스파이더맨: 노 웨이 홈', '스파이더맨의 변천사를 보는 재미가 있었다.', '8']
# ['음양사 : 청아집', '2편 나올것인가?  <나루토>  구미, 우치아이 마다라-나루토-', '8']
# ['돈 룩 업', '풍자영화의 끝판왕. 마지막은 뭉클했다. 감독 능력 진짜 인정해야할듯', '10']
# ['캡틴 판타스틱', '수작입니다. 오랜만에 좋은 영화를 보았네요.', '10']
# ['경관의 피', '좋아하는 배우 분들 나온다고 해서 엄청 기대했는데 기대 이하였음 대사 잘 안 들리는 것도 그렇고 내 귀가 이상한가 싶었는데 암튼 제 기준 영화값 아까운 영화였어요ㅠㅜ,,', '4']
# ['스파이더맨: 노 웨이 홈', '조온나 재밌어요 그냥 봐', '10']
# ['고스트버스터즈', '의외로 상당히 괜찮았던 리메이크작. 대체적으로 원작과 제목에 충실하게 유령들도 많이 나오고 유령잡는 팀 답게 고전의 맛이 나는 기계 장비들을 사용하여 나름 원작을 존중하는 모습도 보여준다. 80년대 원작 시리즈에 출연했던 원조 배우들의 카메오 출연들도 반가웠고, 지금 들어도 여전히 신나는 메인 테마 브금은 역시는 역시였다.', '8']
# ['경관의 피', '도대체 뭐라고 하는거야?', '1']
# ['씽2게더', '코로나 시국에 가장 그리운건 신나고 흥미로운 공연을 맘껏 접할수 없었는데..눈이 즐겁고 발이 쿵쿵거리는 무대 대신 이 영화 한편이 그동안의 아쉬움을 꽉 채워줍니다.꼭 보세요.', '10']
# ['씽2게더', '간만에 태런 목소리듣고 좋았다ㅎㅎ', '10']
# ['경관의 피', '최우식 배우 너무 멋졌어요ㅠㅠ 경관의 피 흥해라!', '10']
# ['빅쇼트', '대중은 개돼지라는 것을 다시한번 되새김하게 됨. 조선에서는 정부의 힘이 매우 강력하여 서브프라임 모기지는 없을 테지만 다른 형태의 비슷한 사건이 조만간 발생할 것이라 예상됨 승리한 개돼지가 되기 위해 노력해야겠음', '10']
# ['위자 : 저주의 시작', '이 OO.+&*7+?+57..ㅋ', '1']
# ['씽2게더', '진짜 재밌음 킬링타임용 영화', '10']
# ['해피 뉴 이어', '너무 울적했는데 마음이 따뜻해졌습니다... 슬픈일있는 사람들에게 큰 힘이 될거라고 생각합니다.', '10']
# ['경관의 피', '원작소설도 읽어보고 싶어지네요 영화는 약간 지루했지만 나쁘진 않았어요', '8']
# ['핵소 고지', '이새끼왜이래 했는데시간가는줄모르고보게됨', '10']
# ['스파이더맨: 노 웨이 홈', '너무많이가서정신없다 ㅜㅜ', '4']
# ['패왕별희 디 오리지널', '어떻게... 어떻게 이렇게 영화 한편에 인생, 사랑, 예술 역사를 절절하게 담을수 있었을까. 할 말을 잃을 뿐. 급변하는 사회, 급변하는 사람들 속 한결같은 예술의 세계. 장국영은 정말 숨막히게 아름답다.', '10']
# ['씽2게더', '이렇게 좋은 영화가 이전처럼 재미가 없다니 나도 나이가 들었나봄', '8']
# ['신은 죽지 않았다 3: 어둠 속의 빛', '크리스찬이라면 꼭 봐야하는 영화', '10']
# ['이미테이션 게임', '방심하고 있는 순간 날카로운 대사가 튀어나와 정신이 번뜩 남! 마지막으로 갈수록 이렇게 슬픈 영화가 없음.. 엔딩크레딧 올라올 때 실화란 걸 알고 펑펑 울어버린 ㅜㅜ 오만 가지 감정을 다 느끼게 하는 영화.', '10']
# ['씽2게더', '너와 처음 보는 영화라서 애니매인션을 안보는 내가 지루하지도 않을만큼 1시간 50분 내내 행복했다.', '10']
# ['13 구역', '스토리가 있는 한시간 반짜리 파쿠르 영상.', '6']
# ['스파이더맨: 노 웨이 홈', '스파이더맨 팬들에게 주는 최고의 선물', '10']
# ['씽2게더', '7살아들과함께 보았는데 아들과 함께 눈물을 퐁퐁 흘렸답니다', '10']
# ['콰이어트 플레이스 2', '1편에 비해 뭔가 짧은 에피소드 같은 느낌. 괴물이 너무 싱겁게 죽어버리는 것도 에러.', '5']
# ['돈 룩 업', '영화를 보고 나면 진지한 세상이 사뭇 코믹해 보임', '10']
# ['보이스', '티빙으로 봤는데 지루하지 않고 시간가는 줄 모르고 잼있게 잘 봤습니다.', '8']
# ['경관의 피', '재밌음 볼만함 ㅇㅌ라ㅓㄱ', '10']
# ['돈 룩 업', '나는 이런블랙코미디가 너무 웃겨ㅋㅋㅋ 마지막 식사장면 좋았음..', '10']
# ['매트릭스: 리저렉션', '아니 3편을 정독한 나로써는 너무나 재밌었음. 줄거리를 자세히 안다면 다 이해가 돼고 그럴법한데 왜 재미없다는 글이 많을까. 매트릭스 팬으로서 너무 재밌었음.', '10']
# ['경관의 피', '일본 소설 원작인데 영화로 만들다보니 중간중간 끊어지는 느낌이었지만 그래도 잘봤다.', '8']
# ['서스페리아', '1977 서스페리아 하고는 완전히 다르다. 그래도 명작.', '10']
# ['가려진 시간', '끝까지 봤네환상적인 이야기에진실이  뭘까???', '8']
# ['나 홀로 집에', '이 영화가 보고싶은 날이 있다메리 크리스마스', '10']
# ['경관의 피', '연기 너무 잘하고 또 보고싶습니당ㅠㅠㅎ', '10']
# ['드라이브 마이 카', '상처받은 자들의 치유하는 방법을 보았다.', '10']
# ['스파이더맨: 노 웨이 홈', '내 젊음을 함께한 스파이더맨', '10']
# ['귀문', '연출 구성이 안타까울따름...시나리오는 좋은데...', '4']
# ['씽2게더', '그냥 최고예요.. 빠질것 하나 없이 모두~~', '10']
# ['경관의 피', '재밌었습니다! 다들 연기 잘 하시고 좋았습니다', '10']
# ['인셉션', '이 영화를 5번보는이유는 이해할려고가아니라5번봐도 이해못하는사람들을 이해할려는거다', '8']
# ['돈 룩 업', '인류적 재앙앞에서 분열되는 모습… 익숙하다.', '9']
# ['사일런스', '화려하진 않지만 영리한 영화. 이야기는 평이하지만 소리의 공포를 밀도감있게 표현한 연출이 즐길거리.', '6']
# ['결백', '어쩔티비~어쩔냉장고', '10']
# ['킹스맨: 퍼스트 에이전트', '시간가는줄 모르게 봤어요ㅋㅋ킹스맨1.2는 본지 오래되어 잘 기억안나서별 생각없이 봤는데 넘나 재밌었음ㅋㅋ', '10']
# ['돈 룩 업', '현실적인 비판과 풍자에 몰입해서 본 영화. 나도 그랬을까 생각이 든다.', '10']
# ['경관의 피', '그냥저냥 평작쯤...', '6']
# ['내가 날 부를 때', '갑자기 엄마가 되었다 중국판', '4']
# ['목소리의 형태', '여주와꾸&작화>>>>x100 스토리', '6']
# ['모가디슈', '긴장감 쩔고 생각보다 재밌음', '8']
# ['찰리와 초콜릿 공장', '스토리가 너무 신선해서 지루하지 않음. 역시나 대단한 감독의 작품이었음.', '10']
# ['씽2게더', '요새 대부분의 애니메이션들과 전작인 씽과는 달리, 성인들에게 인상을 줄 만한 요소는 별로 없었습니다. 뻔한 스토리와 클리셰, 극단적으로 낙관하는 스토리로 진행되기 때문에 어떻게 진행될 지 예상이 됩니다. 또한 다소 정신없고 산만한 진행은 몰입조차 방해합니다. 이러한 점에서 약간 실망했네요. 그러나 어린이들과 함께 보시면 괜찮을 영화라고 생각합니다. 희망적인 이야기를 더 좋아할 테니까요.Ost도 뭐.. 그닥 맘에 들지는 않았습니다만 유명한 노래들이긴 합니다.마지막에 나오는 ost는 마음에 들었습니다. 좋네요.', '4']
# ['더 파더', '마지막에 아버지가 아기가 되어 간호사 품에 안겨 우는 모습에 가슴이 미어졌네요', '10']
# ['킹스맨: 퍼스트 에이전트', '누가 재미없대.. 너무 좋았어요', '10']
# ['씽2게더', '인간도 짐승도 아닌 것이 내 맘을 항상 울린다..??', '10']
# ['장르만 로맨스', '제목 그대로 어떤 장르인가요', '2']
# ['경관의 피', '믿고보는 배우들.. 잘봤습니당!', '10']
# ['트루먼 쇼', '명작이다 진짜... 이 영화를 왜 이제야 봤지..? 24년이나 됐지만 내용도 너무 신선하고 생각이 많아진다', '10']
# ['1987', '역사를 잊은 민족에게 미래는 없다/ 대한민국 국민이 꼭 봐야할 영화', '10']
# ['해피 투게더', '최고였다 그냥 그냥 최고였고 눈물이 났다', '10']
# ['진짜로 일어날지도 몰라 기적', '기적이 일어나든 일어나지 않든아이들은 성장해 나간다.', '10']
# ['죽지않는 인간들의 밤', '스토리 뻔하고 개그코드도 뻔하지만 b급 감성 코미디 좋아하는 사람들이 환장하는 영화. 요새 이런 영화 끊긴 줄 알았는데 여기 있었다..ㅠ 뻔해도 재밌다.', '10']
# ['고스트버스터즈 라이즈', '그냥 쏘쏘 하네요……..', '7']
# ['씽2게더', '진짜 1편보다더 더 더 재미있고 흥미로웠다얘기가 알수없이 반전의 반전의 반전!!!1편은 노래가 최고엿는데2편은 영상미와 더욱더탄탄한 내용을가지고왔다노래도 좋고진짜 거의 3년을 기대하며 기다렷는데이렇게 보면서 행복햇던적은 손에꼽는다.기다림이 후회되지않음보는내내 설렜다.3도 나왓으면 좋겠다.만드신 분들이 얼마나 열심히 준비했는지그냥 이해가된다.무조건 고민없이 꼭 극장에서보세요!!!', '10']
# ['파이란', '와 이거 내플릭스 올라와서 20년만에 두번째 보는데 완전 명작이었에요 ㅜ 미쳤다 최고 장백지도 이 시절 리즈 찍었네요 한국영화의 힘!!', '10']

# %% [markdown]
# ## 2-2. 네이버 영화 데이터 셋 제작 (30점)
# `CSV` 파일로 저장된 데이터를 쉽게 접근하기 위해서는 파이썬 내에서 구조화할 필요가 있습니다.
# 이를 위하여 데이터에 접근 가능한 `RawMovieReview` 클래스를 만들어 봅시다.
#
#
# ### `RawMovieReview` 클래스는 다음을 준수해야 합니다.
# 0. 이하 모든 클래스 공통 사항
#     * 클래스 속성은 사용이 금지됩니다.
#     * 전역 변수 사용이 금지됩니다.
# 1. 생성자
#     * 생성자의 인자는 `str`타입의 `file_name` 하나만을 받습니다.
#     * `file_name` 인자의 기본값은 `"samples.csv"`입니다.
#     * 해당 객체는 해당 파일을 다루는 객체가 되어야 합니다.
#     * 모든 속성 값은 `protected` 홋은 `private`이어야 합니다. 즉, 메소드만 `public`입니다.
# 2. Indexing
#     * 대괄호로 N번째 sample에 접근할 수 있어야 합니다.
#     * N은 0부터 시작합니다. 즉, `dataset[0]`은 첫번째 한줄 평 입니다.
#     * Indexing 결과값은 `영화 이름, 한줄평, 점수`로 타입은 `(str, str, int)` 형태의 튜플입니다.
#     * 대괄호로 읽기만 가능하고 수정은 불가능해야 합니다.
# 3. Length
#     * `len(dataset)`의 형태로 데이터셋 내의 한줄평 개수를 조회할 수 있어야 합니다.
#
# ### 과제를 제출하실때 다음을 제출해야합니다.
# 1. `RawMoviewReview` 클래스가 정의된 코드 (`.py` 혹은 `.ipynb`)

# %%
class RawMovieReview:
    def __init__(self, fileName: str = 'samples.csv'):
        self._fileName = fileName
        self._data = []
        
        with open(self._fileName, 'r',encoding = 'utf-8-sig') as f:
            reader = csv.reader(f, delimiter=',',
                      quotechar='"',
                      quoting = csv.QUOTE_MINIMAL)
            for row in reader:
                self._data.append(row)
        self._data = self._data[1:] # remove columns (movie, sentence, score)
        
        
    def __len__(self):
        return len(self._data)
    
    def __getitem__(self, index):
        self._title = str(self._data[index][0])
        self._sentence = str(self._data[index][1])
        self._score = int(self._data[index][2])
        return tuple([self._title, self._sentence, self._score])

# %%
raw_data = RawMovieReview()
print(f"데이터 타입 : {type(raw_data[100])}") # 튜플 데이터 타입.
print(f"한줄 평 : {raw_data[100]}") # 101번째 한줄 평.
print(f"데이터 한줄 평 개수 : {len(raw_data)}") # 데이터 셋 내의 한줄 평 개수 조회.
print(type(raw_data[100][0]))
print(type(raw_data[100][1]))
print(type(raw_data[100][2]))
# Out:
# 데이터 타입 : <class 'tuple'>
# 한줄 평 : ('위시 드래곤', '재미는 있으나, 구성은 알라딘', 6)
# 데이터 한줄 평 개수 : 1014
# <class 'str'>
# <class 'str'>
# <class 'int'>

# %% [markdown]
# ## 2-3. 네이버 영화 학습 데이터 셋 제작 (30점)
# 위에서 제작한 데이터 셋은 `CSV` 파일을 모두 조회하지만, 학습에 바로 사용되기에는 다소 불편합니다.
# 따라서 이를 상속한 `MovieReview`를 만들어 봅시다.
#
# ### `MovieReview` 클래스는 다음을 준수해야 합니다.
# 1. 상속
#     * 위에서 정의한 `RawMoviewReview` 클래스를 상속받아야합니다.
#     * `RawMoviewReview` 내의 데이터를 복사하면 안됩니다.
#     * 즉, 저장된 `CSV`파일은 부모 클래스의 속성 혹은 메소드로 접근해야합니다.
# 2. 생성자
#     * 생성자의 인자는 부모의 인자와 `int`타입의 `score_threadhold`를 받습니다.
#     * 해당 클래스에는 `CSV`파일 및 그 내용이 속성으로 들어가면 안됩니다.
#     * 즉, 영화 데이터는 부모에만 저장되어야합니다.
# 3. Indexing
#     * 부모의 Indexing을 재정의합니다. (Overriding)
#     * 기본적인 기능은 부모의 기능과 비슷하나 이하의 사항이 다릅니다.
#     * Indexing 결과 값은 `한줄평, 긍부정`으로 타입은 `(str, bool)` 형태의 튜플입니다.
#     * 점수가 객체의 `score_threadhold` 이상일 경우 긍정이 `True`, 미만이면 `False` 입니다.
#     * 한줄평 string의 경우 양쪽에 공백이 없어야 합니다.
#
# ### 과제를 제출하실때 다음을 제출해야합니다.
# 1. `MoviewReview` 클래스가 정의된 코드 (`.py` 혹은 `.ipynb`)

# %%
class MovieReview(RawMovieReview):
    def __init__(self, fileName: str = 'samples.csv', ScoreThr: int = 5): # Score thr 1 ~ 10
        super().__init__()
        self._ScoreThr = ScoreThr
        
    def __getitem__(self, index):
        if int(super().__getitem__(index)[2]) >= self._ScoreThr:
            return str(super().__getitem__(index)[1]), True
        else:
            return str(super().__getitem__(index)[1]), False

# %%
review = MovieReview()
for i in range(1,100):
    print(review[i])
# Out:
# ('신념 있는 로비스트는 자신의 승리만을 믿지 않는다.', True)
# ('마지막 급박한 순간조차도 비로소 둘이 함께 일 때 가장 편안하고 안락함을 느꼈던 두 사람의 우정.', True)
# ('암살을 눈탱이질한 후에 영감을 받았다며 일을 벌인 장이모우의 최후...태극기 휘날리며 눈탱이질한 집결호 만큼이나 뜬금없다...', True)
# ('이소룡 몸과 표정을 보고 있으면 시간이 후딱 지나감.', True)
# ('쥐가 캐리한 영화 ㅋㅋㅋㅋ', True)
# ('원작도 재밌게 읽었는데 원작만큼 재밌었어요', True)
# ('두꺼비는 내 인생 최고의 악역이다ㅋ아직도 줘패주고싶네 두꺼비새끼 (칭찬임)', True)
# ('마지막 장면 30분은 그냥 최고... 꼭 영화관에서 보세요', True)
# ('병두야 연기 때려치자 그냥', False)
# ('보면서 물음표가 많이 나오는 영화였어요 뭔가 말하고 싶은것은 많는데 제대로된 메시지는 없는 난잡한 스토리였어요', True)
# ('마음이 간드러지는 영화', True)
# ('영상미가 너무좋네요 뿜뿜', True)
# ('잠깐 나온 이문식 연기력만 10점 준다 ㅋㅋㅋㅋ진짜 남는거 아무것도 없이 기분만 더러운 영화', False)
# ('왜 인간은 인간이 갈길을 모르는걸까', True)
# ('쓸대없이 여배우 안쓰고 간만에 재밌게본 한국영화', True)
# ('코로나 장기화로 지친 시기에 만나는 역대급 블록버스터', True)
# ('재밋어요 지루하지않아요!!!', True)
# ('최고~개인적으로 1편보다 좋았음', True)
# ('이게 바로 진짜 헐리우드 B+급이지 ㅋㅋㅋㅋ', False)
# ('아 그때 그 추억. 짜릿한 등장.', True)
# ('소름이돋는 연기… 지금의 저 배우들을 보면 정말저 시대와 같은 분들이었을까라는의심에 더 소름이 돋는다…배우는배우다!!!', True)
# ('액션도 스토리도 지금까지 시리즈 중 최고였어요 ㅠㅠ 꼭보세여', True)
# ('옛 스파이더 주인공들과 현 스파이더맨 한 화면에 나올줄이야.. 정말 상상도 못했습니다. 어린시절 추억들과 지금의 감성까지 모두 다 잡은 최고의 영화!', True)
# ('사랑스러운 영화 ^^ 벌써 30년이나 되었네요', True)
# ('2021 최고의 영화', True)
# ('너무재미있었습니다 진짜 최근본 영화중 원탑', True)
# ('썰렁한 괴담', False)
# ('옛날에 참 재밌게 봤던 기억이 있어서 오랜만에 다시 봤는데…무려 13년 전 영화. 어릴때 봤던거라 그냥 아무것도 모르고 재미있었던거였음. 지금 보니 억지스러운게 한 두가지가 아님. 그냥 다 쓰러지고 터지고 하니까 재밌었던거지 ㅋㅋ 그래도 재난영화는 좋아하는 편이라 무난하게 봄', True)
# ('사랑 그 이전의 결핍에 대하여', True)
# ('영상미는 완벽 ..대사가 많아 조금 힘들었음', True)
# ('영화가 정신사납기만하네초반에 뜬금없이 맥주병으로왜때리는거요', False)
# ('good for 10 years old child', True)
# ('명작은 다시봐도 명작 ...', True)
# ('와 감상포인트 뭘 눌러야할지 모르겠네다섯개 다 해당 안하는데??? 이렇게 애매한 영화는 처음임그나마 연출? CG는 진짜 별론데마지막에 물탱크 등장하는거에서 어이없게 웃어서 그거 하나때문에 별 4점이라도 줌.개인적으로 배우진들 진짜.. 다 좋아하는데 이 배우들 갖다놓고 이렇게 찍었다는게…', False)
# ('먼저 본 사람들이 눈물이 날거야라고 해서.. 무슨 신파길래 눈물 타령인가.. 난 관심없다 했는데.. 왜 눈물이 날거라고 얘기했는지 알겠음.파커 파커 파커', True)
# ('썸남이랑 보러 갔었는데 영화가 너무 엄청나서 아무 일도 일어나지 않았습니다.', True)
# ('영화가 아니라 다큐보는 기분..', True)
# ('소년의 성장을 담은 영화', True)
# ('오랜만에 느껴보는 호흡 ㅜ 너무 잘봤습니다', True)
# ('좋아하는 노래 ^^너무 예쁜 소피마르소^^', True)
# ('이거만큼 쾌감쩌는영화 본적없음', True)
# ('산드라블록의 연기가 최고..', True)
# ('서양 세계사를 아는 사람은 더 재밌게 볼 수 있어요.', True)
# ('개 노 잼 & 개 연 성 없 음그냥 윤계상 한예리가 귀여움', False)
# ('앤드류의 연기가좋고 넘버들도 완벽', True)
# ('뭔 스토리도 없고 그냥 호빠들 자잘한 거짓말과 사기만 치는 얘기말고 암것도 없고 내용자체도 더러움', False)
# ('현실반영이 잘된 영화지만 나에겐 웃기지는 않은 ..', True)
# ('거울을 이용한 연출이 좋았던 영화', True)
# ('다시 마블을 찾아보기 시작했다', True)
# ('6점도 높은거… 크리스 헴스워스 연기때문에 다 봤음. 스토리가 엔간치 해야지 뻔하디 뻔한 스토리에… 애 하나 구하겠다고 손해를 얼마나 본거냐. 돈도 못 얻고 팀원도 잃고~ 그래도 액션씬 하나는 볼만했음. 연출은 우리나라식 B급 갬성을 보는 것 같아 영 별론데 액션씬 + 연기력 하나 때문에 6점 줌.', True)
# ('정말 재밌고 감동적으로 본 영화임.예전 영화관에서 봤는데 오늘 TV에서 다시 보니추억의 명화를 다시 접해서 행복하네요.', True)
# ('보는 중에는 되게 자기 파괴적이라고 생각했으나 그녀에게서 나를 보았다. 스스로에겐 확신이 없고 외로운, 순간순간 아끼는 사람들에게 온전히 마음 내어주고 휩쓸리는 그녀란...', True)
# ('예전시리즈와는 다른 재미!', True)
# ('너무…아무생각없이 봤다가 질질짰어요ㅠㅠㅠ 아진짜ㅠ', True)
# ('중반까지는 좋았으나 결말에 이를수록 오히려 긴장감이 풀어지며 이야기가 흐지부지 되는 느낌. 그리고 대사 전달력이 별로 안 좋다.', True)
# ('보는내내 재밌어요. 추천', True)
# ('개인적으로 성공적인 리부트라 생각합니다.재밌게 봤어요...마지막에 이곤이 나왔을 땐...감동적이었습니다.', True)
# ('맘껏 기대해도 좋은 스파이더맨 최고영화!', True)
# ('제 인생을 되돌아보게된 영화 선물 감사합니다.', True)
# ('이 영화가 천만을 못 찍으면 충격일듯. 코로나 시국 속 최고의 히어로 무비', True)
# ('진짜 감동적이다 3스파', True)
# ('전 재밌게 봤습니다. 1,2,3편을 보지 않았던 터라 매트릭스 세계관을 수박 겉핥기식으로 알고 있었는데요. 덕분에 내용에 혼돈이 쎄게 와서 나무위키를 참고하며 보았습니다. 스토리를 알고나니 무척이나 재밌더라구요. 그리고 매트릭스 1,2,3편이 보고 싶어지더군요. 다만 네오와 트리니티의 초인적인 능력은 마블 슈퍼 히어로급이던데요. 액션신은 볼만했습니다.근데 여기도 PC가 묻었는지, 조금 그런 배역들이 보이더라구요. 매트릭스 포에버. 다음 작품도 기대하겠습니다! 역시 명불허전이네요~', True)
# ('1편보다 커진 스케일과 화려한 영상, 그리고 흥겨운 음악들이 즐거움을 선사한다. 다만 스토리는 여전히 아쉽다.', True)
# ('명작이다 이 감정을 말로 표현 못하겠다 ,추천합니다', True)
# ('히어로영화 잘 안 보는데도 재밌게봤음', True)
# ('재미있었나요? 야금야금 환경오염으로 종말을 맞이중이지만 아무도 플리스틱과 비닐,기름의 사용을 멈추지 않는 우리의 진짜 현실을 풍자한겁니다.', True)
# ('중반 이후부터는 그냥 삼류 판타지 영화.', True)
# ('혜성대신 백신을 대입하면 딱 맞네요', True)
# ('ㄹㅇ 코시국만 아니었으면 1000만 영화임 ㅇㅈ', True)
# ('한국에서 이런 수작이 나오다니sf 특성상 약간의 오류들이 아쉬웠고액션이 좋기도하면서도 아쉬웠다', True)
# ('이전보다 절제된 영상미, 시리즈물로 거듭나기 위한 밑거름이 되는 작품', True)
# ('문재앙 ~.~ ~.~ ~.~', True)
# ('진짜 악역은 누구일까....', True)
# ('대존잼입니다. 진짜 눈물질질짜는 신파포인트없고 깔끔하고 좋았습니다.조진웅이 조진웅했다. 최우식이 최우식했다. 기생충지하방아저씨도 한몫했다!', True)
# ('예고편에서 기대했던 것 보다 뭔가 아쉬운 느낌.', True)
# ('치유를 위한 억지설정들', False)
# ('야 이거 뭐냨ㅋ크케켁 시간 순삭', True)
# ('올해 최고의 영화', True)
# ('최고중에 최고지  역대급임', True)
# ('아니 이 명작이 왜 평점이 이따위냐?이건 그야말로 작품이다', True)
# ('만화 뮬란이 워낙 인상이 깊다보니 꼭 보고 싶어서 망작이라는 이야기를 들었지만 봤습니다. 하.. 남의 말은 주의깊게 들어야 하는건데 ... 아니 그 명작을 어떻게 이렇게까지 할 수가 있지. 뮤지컬은 어디로 사라지고 설정은 개판에 감동도 없고 진짜 미쳤나 정신이 나갔나 하 개열받네 내 감동 돌려내라. 그래도 배우 캐스팅을 좀 해서 연기는 그럭저럭? 그런 개떡같은 설정에도 괜찮더군요. 생각없이 보면 볼면할지도 모르겠네요.', False)
# ('잠시나마 그들의 고통에 공감할 수 있었다. 마냥 재밌게 볼 수 있는 영화는 아닌듯.', True)
# ('진짜 저만 재미없게봤나. 평점들이 좋네요. 명품배우들 모시고 .. 기대가 컸나. . 최근본 영화 강릉 영화보다 한수위네요. ㅜ', False)
# ('너무 감동 ㅜㅜ 엄청 울었네 ㅜㅜ', True)
# ('안타깝고 마음찡하네요 오래도록 제맘속에 남을거에요 세번째 봅니다', True)
# ('부활하지 말았어야할 영화', False)
# ('좋은영화입니다 꼭 보세요 짱 입니다', True)
# ('한 4점쯤 주고 싶은데 10점 주는 알바들 때매 1점 줌. 지루하고 폼잡는 90년대 한국영화 본 느낌… 보다가 마스크까지 끼고 내가 뭘보고 있나 싶었음', False)
# ('영화시작 10분도 안돼서 신파 깔기 시작. 그래 신파 좋다 이거야. 근데 브금은 무슨 영화 끝나는 수준으로 웅장함 ㅋㅋㅋ', False)
# ('다른말 필요없음,,진짜 최고였어요!!!', True)
# ('유튜브로 하이라이트만 보는데도 오글거려서 스킵하면서 봤네요', False)
# ('간만에 본 재미 있는 영화~', True)
# ('재밌게 봤어요!! 개인적으로는 스파이더맨보다 재밌게봄..', True)
# ('중반 9점 후반 5점 전종서10점', True)
# ('이 영화를 보고 확신이 생겼다. 일본은 정신분열 상태에 빠져있다.', False)
# ('연기를 다들 잘하셔요~', True)
# ('2차 대전 다큐 보고 봤더니 더 감동이다.', True)
# ('애ㅅㄲ들은 뒤ㅈ는게 맞다', True)
# ('감사합니다', True)

# %% [markdown]
# ## 최종 제출
# * 모든 파일을 `zip`으로 압축하여 `HW2_<한글 이름>.zip` 형태로 제출합니다.

# %% [markdown]
# ## 채점 기준 표
# 각각의 문제에 대해서 이하의 감점이 각각 들어갈 수 있습니다. 음수 점수는 없습니다.
# 아래의 채점 기준표는 확정이 아니며, 추후 수정된 점수 기준이 적용될 수 있습니다.
#
# 감점요소 | 설명 | 감점 점수
# -----|-----|-----
# API 문서와 다른 입출력 | 과제 내 명시된 API 및 포멧과 입출력이 다릅니다. | -15
# 비효율적인 시간복잡도 | 시간복잡도가 최선이 아닙니다. (크롤링 $O(N)$, Indexing $O(1)$)| -10
# 비효율적인 공간 구조 | 부모 자식간 데이터가 중복하는 형태로 클래스가 작성되어 있습니다. | -10
# 명시되어 있지 않은 외부 라이브러리 사용 | 지정된 라이브러리 외에 다른 라이브러리를 사용하였습니다 | -10
# 권장하지 않는 문법 | 전역 변수나 클래스 속성을 사용하였습니다. | -10
